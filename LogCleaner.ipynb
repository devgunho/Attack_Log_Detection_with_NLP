# %%
TARGET_FILE = "./Loghub/Spark/Spark_2k.log"

# %%
file = open(TARGET_FILE,"r")
lines = file.readlines()

line_cnt=0
target_line=""
for line in lines:
    line_cnt += 1
    target_line = line.strip()
    # print(line.strip())

# %%
def line_cleaner(line):
    # print(line)

    for char in line:
        is_num = False
        is_big = False
        is_small = False

        print(int("0"))
        print(int("9"))

        if "0" <= char:
            print(char,"over 1")
        if "9" >= char:
            print(char, "over 9")
        print(char)

# %%
line_cleaner(target_line)
# Out:
# 0
# 9
# 1 over 1
# 1 over 9
# 1
# 0
# 9
# 7 over 1
# 7 over 9
# 7
# 0
# 9
# / over 9
# /
# 0
# 9
# 0 over 1
# 0 over 9
# 0
# 0
# 9
# 6 over 1
# 6 over 9
# 6
# 0
# 9
# / over 9
# /
# 0
# 9
# 0 over 1
# 0 over 9
# 0
# 0
# 9
# 9 over 1
# 9 over 9
# 9
# 0
# 9
#   over 9
#
# 0
# 9
# 2 over 1
# 2 over 9
# 2
# 0
# 9
# 0 over 1
# 0 over 9
# 0
# 0
# 9
# : over 1
# :
# 0
# 9
# 1 over 1
# 1 over 9
# 1
# 0
# 9
# 1 over 1
# 1 over 9
# 1
# 0
# 9
# : over 1
# :
# 0
# 9
# 1 over 1
# 1 over 9
# 1
# 0
# 9
# 1 over 1
# 1 over 9
# 1
# 0
# 9
#   over 9
#
# 0
# 9
# I over 1
# I
# 0
# 9
# N over 1
# N
# 0
# 9
# F over 1
# F
# 0
# 9
# O over 1
# O
# 0
# 9
#   over 9
#
# 0
# 9
# s over 1
# s
# 0
# 9
# t over 1
# t
# 0
# 9
# o over 1
# o
# 0
# 9
# r over 1
# r
# 0
# 9
# a over 1
# a
# 0
# 9
# g over 1
# g
# 0
# 9
# e over 1
# e
# 0
# 9
# . over 9
# .
# 0
# 9
# B over 1
# B
# 0
# 9
# l over 1
# l
# 0
# 9
# o over 1
# o
# 0
# 9
# c over 1
# c
# 0
# 9
# k over 1
# k
# 0
# 9
# M over 1
# M
# 0
# 9
# a over 1
# a
# ...
