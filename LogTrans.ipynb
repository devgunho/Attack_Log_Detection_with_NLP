# %%
import os
import random

TARGET_FILE = "./clean_text/Windows_2k.log_clean.txt"
TARGET_FILE = "./clean_text/Linux_2k.log_clean.txt"

# %%
# Windows
def get_rand_word(line):
    line = line.strip()
    line_list = line.split()
    # print(line_list)
    remove_tok_cnt = 7
    line_list = line_list[remove_tok_cnt:]
    random_tok = random.sample(line_list, k=2)

    loop = 0
    while str(random_tok[0]).isnumeric()==True or str(random_tok[1]).isnumeric()==True or (len(random_tok[0]) + len(random_tok[1])<=2) or len(random_tok[0])==1 or len(random_tok[1])==1:
        random_tok = random.sample(line_list, k=2)
        loop+=1
        if (loop==10):
            break;
        print(random_tok)

    return random_tok

# %%
file_cnt = 1

while True:
    file = open(TARGET_FILE,"r")
    lines = file.readlines()

    result_file_name = os.path.split(TARGET_FILE)[-1]
    result_file = open("concordance_"+str(file_cnt)+"_clean.lam","w")

    for line in lines:
        target_line = line.strip()
        random_tok = get_rand_word(target_line)
        result_file.write(f"exists x1.(_{random_tok[0]}(x1) & exists x2.(_{random_tok[1]}(x2) & (x1 = x2)))"+"\n")

    result_file.close()
    file_cnt+=1
    if file_cnt == 21:
        break;
# Out:
# ['tty', 'logname']
# ['nodevssh', 'failure']
# ['135', '0']
# ['failure', 'rhost']
# ['ip', '220']
# ['ruser', 'ip']
# ['tty', 'nodevssh']
# ['0', 'unix']
# ['ruser', 'authentication']
# ['pam', 'session']
# ['23397', '4']
# ['logname', 'rhost']
# ['unix', 'tty']
# ['188', 'rhost']
# ['euid', '2']
# ['218', '2']
# ['logname', 'rhost']
# ['23406', 'user']
# ['unknown', 'unix']
# ['nodevssh', '2']
# ['failure', 'logname']
# ['pass', 'unix']
# ['4', 'tty']
# ['23394', 'unix']
# ['tty', '188']
# ['4', '2']
# ['tty', '218']
# ['rhost', 'tty']
# ['unknown', 'user']
# ['pam', '0']
# ['tty', 'ruser']
# ['unix', 'failure']
# ['23412', 'user']
# ['pam', '23412']
# ['23412', 'check']
# ['check', 'unknown']
# ['failure', '4']
# ['rhost', '4']
# ['pam', '218']
# ['2', 'pam']
# ['2', 'failure']
# ['logname', 'unix']
# ['23414', 'euid']
# ['4', '2']
# ['4', 'ruser']
# ['authentication', '2']
# ['23414', 'logname']
# ['unix', 'ruser']
# ['0', 'tty']
# ['0', 'nodevssh']
# ['logname', 'ctinets']
# ['0', 'nodevssh']
# ['pam', '0']
# ['0', 'logname']
# ['uid', 'unix']
# ['user', 'unix']
# ['ruser', 'nodevssh']
# ['pass', 'unknown']
# ['logname', 'euid']
# ['pam', 'unix']
# ['24141', 'nodevssh']
# ['logname', '116']
# ['uid', 'tty']
# ['unix', '24140']
# ['254', 'unix']
# ['net', '24140']
# ['uid', '0']
# ['pam', 'd211']
# ['net', 'tty']
# ['with', 'abnormally']
# ['adelphia', '24']
# ['from', 'net']
# ['76', 'adelphia']
# ['bflony', 'adelphia']
# ['adelphia', '29507']
# ['from', '24']
# ['07', '17']
# ['29507', 'net']
# ['00', 'jun']
# ['76', '76']
# ['jun', '76']
# ['07', '24']
# ['17', 'jun']
# ['net', '76']
# ['24', '17']
# ['07', 'fri']
# ['jun', '216']
# ['17', '00']
# ['17', '24']
# ['fri', 'net']
# ['bflony', '17']
# ['fri', '07']
# ['00', '76']
# ['54', 'from']
# ['29509', '24']
# ['07', 'jun']
# ['216', '76']
# ['from', '76']
# ['net', '07']
# ['07', 'at']
# ['07', '29510']
# ['24', '216']
# ['24', 'at']
# ['54', '216']
# ['net', 'bflony']
# ['29511', '76']
# ['76', '216']
# ['24', 'at']
# ['from', 'bflony']
# ['failure', '46']
# ['authentication', 'uid']
# ['17', '162']
# ['82', '252']
# ['82', '81']
# ['162', '162']
# ['lns', 'from']
# ['81', 'adsl']
# ['252', 'adsl']
# ['lns', '252']
# ['lns', '20']
# ['from', '55']
# ['vlq', 'fri']
# ['fri', '252']
# ['06', '252']
# ['at', '2005']
# ['2005', 'proxad']
# ['162', 'jun']
# ['net', '162']
# ['from', 'connection']
# ['30758', 'adsl']
# ['proxad', '17']
# ['tou', '45']
# ['20', 'at']
# ['162', 'lns']
# ['at', '17']
# ['162', 'net']
# ['adsl', '162']
# ['82', 'connection']
# ['45', '252']
# ['162', '81']
# ['252', '2005']
# ['at', 'net']
# ['unix', 'pass']
# ['0', '70']
# ['dsl', 'tty']
# ['user', 'check']
# ['242', 'pam']
# ['authentication', '0']
# ['242', 'unix']
# ['tty', 'nodevssh']
# ['rhost', '75']
# ['failure', 'authentication']
# ['ksc2mo', '75']
# ['70', '75']
# ['logname', '70']
# ['ksc2mo', 'failure']
# ['31206', 'check']
# ['check', 'pam']
# ['euid', '0']
# ['rhost', '70']
# ['tty', 'failure']
# ['unix', 'ksc2mo']
# ['81', '02']
# ['connection', '08']
# ['lns', 'tou']
# ['08', 'jun']
# ['162', '18']
# ['proxad', '08']
# ['08', 'vlq']
# ['81', 'tou']
# ['connection', '81']
# ['18', '31273']
# ['82', '162']
# ['adsl', 'tou']
# ['2005', 'sat']
# ['vlq', '45']
# ['31274', 'connection']
# ['at', 'vlq']
# ['vlq', '10']
# ['at', '162']
# ['sat', '18']
# ['adsl', 'sat']
# ['adsl', 'at']
# ['jun', '252']
# ['45', '31277']
# ['82', '81']
# ['252', '162']
# ['from', '82']
# ['31277', 'connection']
# ['81', '162']
# ['at', '162']
# ['connection', 'at']
# ['tou', '252']
# ['82', '162']
# ['252', '252']
# ['connection', '81']
# ['from', '81']
# ['vlq', '08']
# ['10', '162']
# ['vlq', '18']
# ['02', '252']
# ['81', 'net']
# ['adsl', '11']
# ['11', '45']
# ['from', '81']
# ['at', '31279']
# ['from', '162']
# ['81', 'from']
# ['2005', '08']
# ['82', '08']
# ['81', '162']
# ['252', '82']
# ['jun', 'sat']
# ['162', '252']
# ['02', 'from']
# ['tou', 'connection']
# ['45', '11']
# ['162', 'tou']
# ['2005', '82']
# ['at', 'from']
# ['jun', '252']
# ['81', '252']
# ['sat', '82']
# ['tou', 'proxad']
# ['adsl', '12']
# ['12', '02']
# ['connection', '82']
# ['162', '81']
# ['162', 'at']
# ['proxad', '82']
# ['lns', '81']
# ['82', 'jun']
# ['lns', 'from']
# ['lns', 'from']
# ['10', 'jun']
# ['900', '2005']
# ['timed', 'out']
# ['for', 'cyrus']
# ['with', '1']
# ['with', 'abnormally']
# ['restart', '4']
# ['1', '1']
# ['1', '4']
# ['1', '4']
# ['4', 'restart']
# ['4', '1']
# ['1', '4']
# ['1', 'restart']
# ['1', '4']
# ['unix', 'pam']
# ['news', '3676']
# ['user', '3676']
# ['news', 'pam']
# ['connection', '40']
# ['at', '8829']
# ['03', '33']
# ['from', 'connection']
# ['90', '59']
# ['2005', 'from']
# ['40', '59']
# ['connection', 'at']
# ['jun', '90']
# ['at', '199']
# ['2005', 'connection']
# ['2005', 'from']
# ['222', 'from']
# ['33', '20']
# ['03', 'at']
# ['at', '33']
# ['40', 'from']
# ['59', '40']
# ['199', '20']
# ['222', '59']
# ['at', '222']
# ['03', '222']
# ['8833', '40']
# ['connection', 'from']
# ['33', '8827']
# ['mon', '20']
# ['jun', 'mon']
# ['8823', '20']
# ['mon', '8823']
# ['jun', 'from']
# ['199', '03']
# ['199', '8825']
# ['at', '20']
# ['222', 'jun']
# ['2005', '40']
# ['at', '222']
# ['at', 'connection']
# ['mon', '03']
# ['at', 'from']
# ['33', '8832']
# ['59', 'from']
# ['2005', '90']
# ['03', '199']
# ['from', '8832']
# ['2005', '03']
# ['connection', '222']
# ['59', '2005']
# ['20', '40']
# ['33', 'connection']
# ['33', 'connection']
# ['mon', 'jun']
# ['199', '90']
# ['2005', 'mon']
# ['from', '2005']
# ['20', '33']
# ['at', '199']
# ['connection', '222']
# ['8831', '03']
# ['222', 'connection']
# ['8831', 'jun']
# ['unix', 'closed']
# ['snmp', 'packet']
# ['nodevssh', 'logname']
# ['unknown', 'user']
# ['unix', '10041']
# ['unix', 'check']
# ['check', 'pass']
# ['0', 'nodevssh']
# ['unix', 'logname']
# ['pam', 'unknown']
# ['159', '65']
# ['failure', 'pam']
# ['10049', 'user']
# ['pam', 'user']
# ['rhost', 'failure']
# ['unknown', 'user']
# ['logname', '14']
# ['failure', '10051']
# ['159', 'failure']
# ['0', 'euid']
# ['65', '159']
# ['0', '10051']
# ['pam', '14']
# ['0', 'euid']
# ['logname', 'unix']
# ['10053', 'uid']
# ['failure', 'euid']
# ['12098', 'user']
# ['unix', 'session']
# ['abnormally', 'alert']
# ['uid', '0']
# ['user', 'ruser']
# ['tty', '0']
# ['60', 'guest']
# ['guest', '217']
# ['0', 'tty']
# ['failure', 'guest']
# ['euid', 'rhost']
# ['unix', 'uid']
# ['unix', 'uid']
# ['user', 'nodevssh']
# ['0', 'ruser']
# ['com', 'rhost']
# ['euid', 'tty']
# ['ruser', '0']
# ['com', 'pam']
# ['logname', '0']
# ['netvigator', 'tty']
# ['uid', 'nodevssh']
# ['rhost', 'failure']
# ['by', 'opened']
# ['exited', 'with']
# ['for', 'unix']
# ['euid', 'ip']
# ['unix', '17124']
# ['user', 'pam']
# ['ruser', 'rhost']
# ['ip', 'secureserver']
# ['check', '17135']
# ['pass', '17135']
# ['user', '17135']
# ['pass', '17135']
# ['unknown', 'pam']
# ['net', '168']
# ['ip', 'failure']
# ['unix', 'pass']
# ['connection', '16']
# ['connection', '22']
# ['245', 'at']
# ['2005', '245']
# ['at', '210']
# ['165', 'connection']
# ['22', 'from']
# ['22', '13']
# ['jun', '16']
# ['jun', '16']
# ['16', '30']
# ['wed', '30']
# ['2005', '136']
# ['22', '165']
# ['13', 'from']
# ['16', '210']
# ['245', 'jun']
# ['from', '136']
# ['210', 'from']
# ['17887', '16']
# ['connection', '30']
# ['30', '17887']
# ['210', '245']
# ['22', '210']
# ['at', '245']
# ['wed', '30']
# ['136', '22']
# ['jun', '16']
# ['165', '210']
# ['165', '17893']
# ['from', '2005']
# ['22', '13']
# ['245', 'jun']
# ['wed', 'from']
# ['136', '30']
# ['from', '136']
# ['210', 'jun']
# ['136', '2005']
# ['30', '16']
# ['from', '2005']
# ['from', '165']
# ['wed', '17879']
# ['jun', '13']
# ['22', '245']
# ['16', '13']
# ['16', '22']
# ['jun', '22']
# ['jun', '2005']
# ['13', 'at']
# ['30', '22']
# ['210', '165']
# ['13', '17892']
# ['165', '136']
# ['17876', '136']
# ['at', '22']
# ['245', '136']
# ['jun', '22']
# ['jun', '210']
# ['17876', '210']
# ['22', '17876']
# ['17876', '2005']
# ['wed', '2005']
# ['connection', '165']
# ['from', 'jun']
# ['245', '17877']
# ['22', '245']
# ['165', 'jun']
# ['245', '22']
# ['245', '16']
# ['at', '30']
# ['2005', '210']
# ['165', '30']
# ['at', '17877']
# ['136', '165']
# ['22', '30']
# ['165', 'jun']
# ['30', '165']
# ['at', '17874']
# ['at', '165']
# ['17874', '30']
# ['165', 'from']
# ['136', 'wed']
# ['at', '22']
# ['17882', 'from']
# ['22', '30']
# ['210', '17882']
# ['13', '22']
# ['jun', '30']
# ['17882', 'wed']
# ['at', '165']
# ['16', '2005']
# ['17881', '245']
# ['136', '2005']
# ['2005', '13']
# ['17881', '22']
# ['wed', 'connection']
# ['136', '165']
# ['210', 'jun']
# ['245', 'jun']
# ['17878', '210']
# ['at', 'connection']
# ['210', 'connection']
# ['2005', '13']
# ['13', '17873']
# ['13', '2005']
# ['30', '13']
# ['13', 'at']
# ['jun', 'wed']
# ['2005', '13']
# ['connection', '13']
# ['13', '17885']
# ['16', '22']
# ['17885', 'at']
# ['31', '16']
# ['165', '245']
# ['210', '165']
# ['wed', 'from']
# ['16', '245']
# ['210', 'at']
# ['31', '13']
# ['22', '2005']
# ['wed', '210']
# ['at', 'from']
# ['17880', '2005']
# ['31', '17880']
# ['136', '22']
# ['from', 'connection']
# ['210', '16']
# ['connection', '16']
# ['245', '13']
# ['13', '165']
# ['31', 'connection']
# ['at', '2005']
# ['connection', '16']
# ['22', 'at']
# ['2005', 'at']
# ['210', 'at']
# ['16', 'from']
# ['136', '165']
# ['at', '31']
# ['jun', '136']
# ['210', '16']
# ['wed', 'connection']
# ['from', 'connection']
# ['user', 'ruser']
# ['logname', 'authentication']
# ['152', 'tty']
# ['failure', 'unix']
# ['0', 'ruser']
# ['209', 'guest']
# ['209', '0']
# ['unix', 'ruser']
# ['logname', 'rhost']
# ['logname', 'unix']
# ['ruser', 'euid']
# ['pam', 'unix']
# ['1', 'alert']
# ['abnormally', 'with']
# ['user', '0']
# ['ruser', 'nodevssh']
# ['unix', '0']
# ['pam', '51']
# ['nodevssh', '22']
# ['nodevssh', 'rhost']
# ['0', 'uid']
# ['rhost', 'failure']
# ['euid', 'root']
# ['unix', 'session']
# ['with', '1']
# ['abnormally', '1']
# ['abnormally', 'alert']
# ['fri', '108']
# ['28568', 'jun']
# ['108', '55']
# ['57', '24']
# ['55', '18']
# ['218', '57']
# ['108', 'fri']
# ['jun', '108']
# ['55', '57']
# ['24', '108']
# ['at', '55']
# ['connection', '11']
# ['55', '108']
# ['18', 'connection']
# ['2005', 'connection']
# ['24', '69']
# ['28562', '11']
# ['218', '69']
# ['2005', 'connection']
# ['28563', '2005']
# ['108', 'at']
# ['connection', '218']
# ['jun', '18']
# ['11', '18']
# ['2005', '18']
# ['2005', '28563']
# ['218', '108']
# ['55', '2005']
# ['at', '108']
# ['69', 'connection']
# ['from', '57']
# ['69', '57']
# ['69', '55']
# ['11', '2005']
# ['2005', 'jun']
# ['69', '55']
# ['108', 'jun']
# ['24', '57']
# ['218', 'at']
# ['11', '69']
# ['2005', '24']
# ['24', '28564']
# ['18', '55']
# ['28564', '24']
# ['at', '57']
# ['57', 'fri']
# ['218', '11']
# ['at', 'from']
# ['57', '28570']
# ['from', '28570']
# ['55', '108']
# ['69', '18']
# ['connection', 'fri']
# ['69', '2005']
# ['108', '69']
# ['at', 'connection']
# ['connection', '108']
# ['from', 'connection']
# ['18', '55']
# ['28572', '18']
# ['28572', '57']
# ['108', '2005']
# ['108', '18']
# ['108', 'jun']
# ['108', '2005']
# ['connection', '108']
# ['57', '218']
# ['18', '2005']
# ['at', '55']
# ['55', '2005']
# ['24', 'from']
# ['18', '24']
# ['18', '28573']
# ['jun', 'fri']
# ['29690', 'user']
# ['unix', '29690']
# ['opened', 'unix']
# ['30934', 'news']
# ['30934', 'closed']
# ['news', 'unix']
# ['user', 'unknown']
# ['0', 'authentication']
# ['failure', 'tty']
# ['unix', 'user']
# ['tty', '0']
# ['merukuru', 'rhost']
# ['0', 'unix']
# ['tty', 'ruser']
# ['unix', 'pam']
# ['unix', 'check']
# ['massive', 'unix']
# ['rhost', 'massive']
# ['at', '25']
# ['connection', '31475']
# ['20', '210']
# ['95', '31475']
# ['jun', 'connection']
# ['jun', 'from']
# ['25', '09']
# ['connection', '24']
# ['from', 'jun']
# ['at', '25']
# ['sat', '24']
# ['170', '118']
# ['24', 'sat']
# ['2005', '210']
# ['118', '31473']
# ['jun', '118']
# ['210', '31473']
# ['09', 'connection']
# ['20', '24']
# ['09', '170']
# ['95', '31467']
# ['20', 'jun']
# ['at', '09']
# ['31467', '20']
# ['31467', 'sat']
# ['31467', 'sat']
# ['connection', '09']
# ['31470', '24']
# ['connection', 'at']
# ['sat', 'from']
# ['31468', 'sat']
# ['24', '09']
# ['95', '31468']
# ['95', '25']
# ['from', '2005']
# ['24', '20']
# ['09', 'at']
# ['118', 'jun']
# ['25', '31468']
# ['09', 'jun']
# ['jun', 'sat']
# ['31471', 'sat']
# ['24', '09']
# ['20', 'connection']
# ['31471', 'from']
# ['connection', '31471']
# ['20', '31471']
# ['210', '2005']
# ['at', '2005']
# ['2005', '25']
# ['118', '09']
# ['31469', '170']
# ['connection', 'from']
# ['210', '95']
# ['24', 'jun']
# ['170', 'at']
# ['24', '210']
# ['95', 'connection']
# ['09', '24']
# ['118', '09']
# ['31462', '210']
# ['jun', 'sat']
# ['from', 'at']
# ['from', '25']
# ['at', 'connection']
# ['24', '20']
# ['sat', '170']
# ['170', '95']
# ['sat', 'from']
# ['167', '25']
# ['sat', 'at']
# ['at', 'from']
# ['211', 'connection']
# ['2005', '30']
# ['jun', '59']
# ['2005', 'jun']
# ['from', 'sat']
# ['2005', '19']
# ['19', 'from']
# ['32326', '68']
# ['connection', '25']
# ['jun', '19']
# ['jun', '25']
# ['25', '30']
# ['sat', '25']
# ['30', '167']
# ['jun', 'connection']
# ['19', '59']
# ['at', 'jun']
# ['2005', '59']
# ['25', '211']
# ['25', '19']
# ['30', 'jun']
# ['2005', '32331']
# ['jun', '68']
# ['sat', '211']
# ['connection', '32331']
# ['211', '32331']
# ['from', '25']
# ['jun', '2005']
# ['30', '25']
# ['19', '2005']
# ['211', '59']
# ['167', '30']
# ['59', '19']
# ['25', '19']
# ['25', '59']
# ['68', '167']
# ['jun', 'at']
# ['2005', '167']
# ['jun', '211']
# ['31', '25']
# ['25', 'at']
# ['jun', '2005']
# ['32332', '68']
# ['68', '2005']
# ['32332', '167']
# ['211', '167']
# ['sat', '68']
# ['25', '31']
# ['jun', '211']
# ['31', '2005']
# ['211', '25']
# ['32334', 'sat']
# ['68', 'jun']
# ['68', 'at']
# ['167', '211']
# ['4', 'restart']
# ['restart', '1']
# ['1', '4']
# ['1', 'restart']
# ['1', '1']
# ['1', 'restart']
# ['1', 'restart']
# ['1', 'restart']
# ['4', 'restart']
# ['closed', 'pam']
# ['news', 'session']
# ['user', 'closed']
# ['ruser', 'pam']
# ['unix', '0']
# ['uid', 'com']
# ['for', 'cyrus']
# ['session', 'for']
# ['11106', 'uid']
# ['session', 'unix']
# ['0', 'pam']
# ['logname', '0']
# ['93', 'root']
# ['ruser', '61']
# ['pam', 'ruser']
# ['root', '11517']
# ['tty', 'pam']
# ['uid', '61']
# ['unix', 'nodevssh']
# ['93', 'unix']
# ['rhost', 'nodevssh']
# ['11514', 'tty']
# ['uid', 'rhost']
# ['uid', 'euid']
# ['0', 'rhost']
# ['euid', 'pam']
# ['user', 'unix']
# ['dsl', 'ruser']
# ['62', 'nodevssh']
# ['ruser', 'uid']
# ['62', 'euid']
# ['authentication', 'user']
# ['authentication', 'user']
# ['94', 'ruser']
# ['uid', 'rhost']
# ['211', 'ruser']
# ['0', 'authentication']
# ['authentication', '115']
# ['authentication', '12756']
# ['uid', 'ruser']
# ['euid', 'nodevssh']
# ['0', '115']
# ['211', '115']
# ['nodevssh', '0']
# ['12755', 'unix']
# ['logname', 'unix']
# ['pam', '12754']
# ['user', 'unknown']
# ['uid', 'logname']
# ['03', '22']
# ['29', '96']
# ['03', 'jun']
# ['jun', '61']
# ['22', '03']
# ['74', '61']
# ['29', '74']
# ['2005', '74']
# ['29', '74']
# ['22', '03']
# ['74', 'from']
# ['connection', '29']
# ['22', '13257']
# ['2005', '22']
# ['jun', '22']
# ['96', '29']
# ['22', 'from']
# ['jun', '96']
# ['at', '2005']
# ['2005', 'from']
# ['13261', 'connection']
# ['29', '22']
# ['178', 'at']
# ['22', 'from']
# ['wed', '22']
# ['connection', 'at']
# ['03', 'jun']
# ['from', 'at']
# ['74', '61']
# ['13252', '29']
# ['22', 'wed']
# ['wed', '178']
# ['61', '22']
# ['jun', '2005']
# ['61', '74']
# ['22', '74']
# ['74', '03']
# ['connection', 'at']
# ['61', '74']
# ['jun', '178']
# ['13256', 'jun']
# ['from', 'wed']
# ['74', '03']
# ['13258', '22']
# ['from', '2005']
# ['at', '2005']
# ['jun', '03']
# ['jun', '96']
# ['61', '178']
# ['03', '61']
# ['178', '61']
# ['29', 'jun']
# ['22', 'wed']
# ['61', 'connection']
# ['jun', '13255']
# ['22', '29']
# ['from', 'jun']
# ['178', '22']
# ['29', '03']
# ['jun', '61']
# ['from', '178']
# ['178', '22']
# ['from', 'connection']
# ['96', 'wed']
# ['178', 'at']
# ['2005', '178']
# ['at', 'jun']
# ['wed', '96']
# ['connection', '13251']
# ['178', '74']
# ['at', '2005']
# ['13251', '178']
# ['from', 'jun']
# ['wed', '96']
# ['96', '29']
# ['22', '22']
# ['from', '03']
# ['29', 'at']
# ['178', '2005']
# ['connection', '22']
# ['from', '22']
# ['at', '178']
# ['178', '96']
# ['22', '74']
# ['wed', '13245']
# ['13245', 'from']
# ['29', '22']
# ['96', 'from']
# ['61', '03']
# ['22', '13245']
# ['29', '74']
# ['178', 'connection']
# ['at', 'connection']
# ['jun', '22']
# ['61', '178']
# ['61', 'at']
# ['jun', 'at']
# ['61', '96']
# ['jun', '61']
# ['at', '61']
# ['at', '61']
# ['wed', '22']
# ['22', 'wed']
# ['22', 'from']
# ['2005', '03']
# ['74', '96']
# ['2005', '22']
# ['29', '13249']
# ['22', '96']
# ['13249', 'connection']
# ['03', 'connection']
# ['connection', 'wed']
# ['61', '03']
# ['22', '22']
# ['jun', '2005']
# ['74', '13253']
# ['22', '74']
# ['connection', '22']
# ['61', '2005']
# ['from', '03']
# ['connection', '74']
# ['connection', 'wed']
# ['0', 'session']
# ['session', 'pam']
# ['unix', 'ruser']
# ['failure', 'ruser']
# ['0', 'rhost']
# ['user', '0']
# ['authentication', 'nsuok']
# ['55', '2005']
# ['01', 'wed']
# ['55', '62']
# ['62', 'from']
# ['48', '15547']
# ['55', 'jun']
# ['2005', '29']
# ['at', 'wed']
# ['at', 'connection']
# ['10', '29']
# ['jun', 'from']
# ['at', '75']
# ['wed', '208']
# ['15542', 'wed']
# ['2005', '208']
# ['75', '29']
# ['15542', '10']
# ['2005', '208']
# ['from', '10']
# ['2005', '55']
# ['at', '62']
# ['jun', '62']
# ['wed', '01']
# ['48', '75']
# ['2005', '208']
# ['48', '2005']
# ['75', 'jun']
# ['48', '55']
# ['at', 'connection']
# ['208', 'from']
# ['55', 'connection']
# ['208', '62']
# ['from', '06']
# ['29', '06']
# ['10', '15549']
# ['2005', '75']
# ['06', 'at']
# ['connection', '208']
# ['from', '06']
# ['55', '15550']
# ['208', '06']
# ['wed', '2005']
# ['75', '2005']
# ['06', '29']
# ['06', '10']
# ['55', '62']
# ['55', '10']
# ['jun', '2005']
# ['connection', 'jun']
# ['jun', 'wed']
# ['at', 'connection']
# ['08', '10']
# ['55', '62']
# ['10', '62']
# ['wed', 'at']
# ['62', 'jun']
# ['55', '48']
# ['48', '62']
# ['48', '2005']
# ['wed', '48']
# ['10', 'from']
# ['48', 'connection']
# ['at', '48']
# ['from', '75']
# ['at', 'jun']
# ['at', 'wed']
# ['62', '29']
# ['at', 'from']
# ['2005', 'jun']
# ['15', '48']
# ['jun', '75']
# ['48', 'connection']
# ['55', 'from']
# ['55', 'wed']
# ['29', '55']
# ['at', 'connection']
# ['wed', 'at']
# ['62', '17']
# ['connection', '10']
# ['at', '17']
# ['75', '2005']
# ['2005', '17']
# ['48', '75']
# ['wed', '48']
# ['10', '75']
# ['wed', 'from']
# ['208', '75']
# ['10', '75']
# ['from', 'at']
# ['2005', '48']
# ['75', 'connection']
# ['wed', '15563']
# ['55', '208']
# ['48', '55']
# ['29', '75']
# ['connection', 'jun']
# ['2005', '29']
# ['75', '29']
# ['connection', 'wed']
# ['user', 'uid']
# ['user', 'authentication']
# ['authentication', 'nodevssh']
# ['pam', '0']
# ['uid', '1']
# ['uid', 'euid']
# ['nodevssh', 'failure']
# ['from', 'wed']
# ['jun', '14']
# ['97', 'wed']
# ['97', '14']
# ['at', '29']
# ['2005', 'from']
# ['at', '210']
# ['29', '14']
# ['from', 'at']
# ['14', '117']
# ['117', '35']
# ['223', '97']
# ['from', '2005']
# ['117', '223']
# ['jun', 'wed']
# ['14', 'connection']
# ['wed', '2005']
# ['at', '210']
# ['44', 'from']
# ['jun', 'from']
# ['44', 'from']
# ['jun', 'wed']
# ['user', '18557']
# ['18557', 'unknown']
# ['unix', 'pam']
# ['ruser', 'biblioteka']
# ['pl', 'pam']
# ['18545', 'pam']
# ['pass', 'user']
# ['unknown', 'user']
# ['logname', 'nodevssh']
# ['224', 'authentication']
# ['224', 'tty']
# ['user', 'unix']
# ['nodevssh', '224']
# ['authentication', '0']
# ['30', 'tty']
# ['ruser', 'failure']
# ['logname', 'unix']
# ['pam', 'ruser']
# ['pam', '30']
# ['euid', '116']
# ['rhost', 'ruser']
# ['root', '129']
# ['failure', '210']
# ['0', '195']
# ['root', '24']
# ['nodevssh', 'root']
# ['0', '24']
# ['pam', '210']
# ['tty', 'rhost']
# ['root', 'failure']
# ['euid', 'nodevssh']
# ['kerberos', 'failed']
# ['authentication', '39']
# ['187', 'failed']
# ['denied', 'from']
# ['27', '27']
# ['163', 'failed']
# ['187', '39']
# ['in', '163']
# ['187', 'in']
# ['39', '187']
# ['permission', '39']
# ['failed', '19286']
# ['permission', '163']
# ['code', 'failed']
# ['failed', '163']
# ['163', 'replay']
# ['authentication', '187']
# ['39', '163']
# ['19270', 'code']
# ['failed', '27']
# ['denied', 'failed']
# ['authentication', 'failed']
# ['code', '163']
# ['from', 'cache']
# ['187', '163']
# ['163', 'denied']
# ['in', '39']
# ['failed', '163']
# ['permission', '187']
# ['163', 'code']
# ['from', 'replay']
# ['39', 'in']
# ['from', '163']
# ['replay', 'permission']
# ['connection', 'software']
# ['failed', '39']
# ['39', 'caused']
# ['39', 'authentication']
# ['163', 'abort']
# ['39', 'failed']
# ['163', 'connection']
# ['27', '163']
# ['19266', '39']
# ['163', 'authentication']
# ['39', 'caused']
# ['19278', '187']
# ['187', 'authentication']
# ['authentication', 'abort']
# ['39', '39']
# ['39', 'software']
# ['163', 'abort']
# ['27', '163']
# ['187', '163']
# ['software', '187']
# ['39', '19273']
# ['caused', 'authentication']
# ['software', 'abort']
# ['27', 'connection']
# ['39', 'from']
# ['39', '163']
# ['39', '27']
# ['caused', 'software']
# ['39', 'connection']
# ['187', 'from']
# ['authentication', '27']
# ['19277', 'connection']
# ['27', 'abort']
# ['27', 'connection']
# ['163', '27']
# ['connection', '187']
# ['163', 'from']
# ['failed', '39']
# ['19279', '27']
# ['163', '27']
# ['connection', 'abort']
# ['27', '27']
# ['authentication', '27']
# ['connection', '163']
# ['from', 'failed']
# ['connection', 'caused']
# ['software', 'authentication']
# ['39', '27']
# ['187', '39']
# ['163', '27']
# ['caused', 'failed']
# ['187', '187']
# ['from', '163']
# ['caused', 'from']
# ['163', 'abort']
# ['19284', 'authentication']
# ['187', 'authentication']
# ['27', '163']
# ['27', '27']
# ['caused', '163']
# ['27', '163']
# ['abort', 'software']
# ['19282', 'authentication']
# ['kerberos', 'failed']
# ['authentication', 'kerberos']
# ['failed', 'kerberos']
# ['uid', 'test']
# ['test', '19431']
# ['for', 'user']
# ['uid', 'pam']
# ['closed', '19432']
# ['closed', 'unix']
# ['closed', 'pam']
# ['user', 'session']
# ['closed', 'test']
# ['user', 'for']
# ['euid', 'unix']
# ['pam', 'ruser']
# ['rhost', 'ruser']
# ['user', '60']
# ['authentication', 'logname']
# ['19643', 'failure']
# ['60', 'root']
# ['ruser', '0']
# ['failure', '224']
# ['116', 'authentication']
# ['uid', 'logname']
# ['session', 'pam']
# ['abnormally', 'exited']
# ['pam', 'for']
# ['21530', 'session']
# ['unix', 'session']
# ['pam', 'session']
# ['21692', 'user']
# ['test', '21692']
# ['pam', 'for']
# ['82', '188']
# ['from', '202']
# ['82', '57']
# ['07', '21951']
# ['from', '82']
# ['07', 'at']
# ['82', '202']
# ['at', '82']
# ['07', '57']
# ['82', '1']
# ['57', 'jul']
# ['from', 'jul']
# ['57', '202']
# ['jul', '82']
# ['200', 'from']
# ['fri', '30']
# ['57', 'connection']
# ['200', 'connection']
# ['30', 'jul']
# ['jul', 'connection']
# ['57', 'jul']
# ['2005', '82']
# ['07', '200']
# ['82', 'jul']
# ['202', '2005']
# ['21954', '202']
# ['57', 'from']
# ['at', 'fri']
# ['from', '1']
# ['07', 'jul']
# ['200', 'jul']
# ['21955', '1']
# ['07', 'fri']
# ['1', '30']
# ['at', '07']
# ['82', 'from']
# ['07', '2005']
# ['jul', '57']
# ['57', '21950']
# ['82', 'fri']
# ['07', 'fri']
# ['188', '200']
# ['1', 'at']
# ['07', '1']
# ['from', '21950']
# ['202', 'jul']
# ['2005', 'jul']
# ['2005', 'connection']
# ['07', '82']
# ['at', 'jul']
# ['57', '07']
# ['57', '30']
# ['from', '200']
# ['1', 'connection']
# ['jul', '82']
# ['202', 'at']
# ['07', '21945']
# ['202', '82']
# ['202', '07']
# ['at', '21959']
# ['connection', '188']
# ['82', 'from']
# ['jul', 'fri']
# ['188', '200']
# ['30', 'jul']
# ['jul', '57']
# ['30', '57']
# ['connection', '30']
# ['82', '1']
# ['at', '200']
# ['07', '2005']
# ['fri', '30']
# ['21941', '202']
# ['fri', '57']
# ['200', '1']
# ['30', '21941']
# ['188', '57']
# ['82', '188']
# ['200', '57']
# ['1', '07']
# ['82', '07']
# ['fri', '30']
# ['fri', 'at']
# ['202', '200']
# ['connection', '57']
# ['2005', '82']
# ['fri', '07']
# ['from', '82']
# ['jul', '1']
# ['jul', '07']
# ['200', 'jul']
# ['from', '07']
# ['07', '1']
# ['30', '07']
# ['fri', '82']
# ['202', '1']
# ['57', 'from']
# ['connection', '82']
# ['07', 'jul']
# ['1', '30']
# ['188', 'connection']
# ['2005', '57']
# ['2005', '200']
# ['1', '188']
# ['21947', '200']
# ['82', '57']
# ['30', 'connection']
# ['connection', '1']
# ['connection', '30']
# ['21947', 'at']
# ['188', '57']
# ['from', '57']
# ['07', 'fri']
# ['82', '21942']
# ['82', '30']
# ['jul', '57']
# ['200', '21942']
# ['at', 'from']
# ['2005', 'fri']
# ['fri', 'at']
# ['fri', 'at']
# ['fri', 'jul']
# ['opened', '509']
# ['session', 'pam']
# ['by', 'unix']
# ['ruser', 'failure']
# ['rhost', 'unix']
# ['failure', '129']
# ['195', 'euid']
# ['failure', 'logname']
# ['509', 'user']
# ['user', 'by']
# ['user', '23534']
# ['23534', 'closed']
# ['23534', 'session']
# ['pam', 'test']
# ['for', 'by']
# ['test', 'pam']
# ['test', 'user']
# ['24117', 'pam']
# ['24117', 'closed']
# ['unix', 'for']
# ['24587', 'pass']
# ['pam', 'user']
# ['0', 'pam']
# ['ruser', 'uid']
# ['euid', 'zummit']
# ['pass', 'unknown']
# ['euid', 'zummit']
# ['user', 'unknown']
# ['check', 'pass']
# ['failure', 'rhost']
# ['pass', 'check']
# ['tty', 'uid']
# ['ruser', 'zummit']
# ['by', 'uid']
# ['1', 'restart']
# ['4', '1']
# ['1', '1']
# ['restart', '4']
# ['restart', '1']
# ['4', '1']
# ['1', '1']
# ['4', '1']
# ['4', 'restart']
# ['101', 'static']
# ['59', 'net']
# ['from', 'at']
# ['dsl', 'net']
# ['chn', 'net']
# ['from', 'sun']
# ['chn', 'connection']
# ['203', 'touchtelindia']
# ['dsl', 'jul']
# ['45', 'from']
# ['32062', 'connection']
# ['45', 'at']
# ['touchtelindia', '2005']
# ['sun', '45']
# ['3', 'static']
# ['2005', '101']
# ['net', 'connection']
# ['059', 'touchtelindia']
# ['from', 'static']
# ['203', 'jul']
# ['static', '203']
# ['203', '059']
# ['chn', '10']
# ['dsl', '25']
# ['2005', 'touchtelindia']
# ['101', '05']
# ['static', '59']
# ['059', '45']
# ['connection', '101']
# ['net', 'from']
# ['203', 'chn']
# ['jul', 'connection']
# ['203', '59']
# ['25', 'dsl']
# ['jul', '10']
# ['jul', 'net']
# ['10', 'sun']
# ['203', 'touchtelindia']
# ['25', '101']
# ['05', '59']
# ['10', 'sun']
# ['touchtelindia', '25']
# ['chn', '101']
# ['59', 'chn']
# ['10', '59']
# ['chn', '3']
# ['3', '45']
# ['101', 'at']
# ['chn', 'dsl']
# ['32056', '10']
# ['203', '10']
# ['45', 'connection']
# ['05', '45']
# ['203', 'at']
# ['sun', '203']
# ['45', 'connection']
# ['59', 'sun']
# ['from', '25']
# ['sun', '101']
# ['059', 'touchtelindia']
# ['2005', '101']
# ['at', 'from']
# ['dsl', 'chn']
# ['101', '59']
# ['connection', '32061']
# ['connection', '05']
# ['connection', 'at']
# ['10', '059']
# ['203', '25']
# ['32055', '10']
# ['10', 'touchtelindia']
# ['sun', '203']
# ['203', 'jul']
# ['3', 'net']
# ['25', '32055']
# ['32055', 'from']
# ['at', '101']
# ['3', '32064']
# ['connection', 'from']
# ['from', '59']
# ['101', '45']
# ['59', '101']
# ['connection', 'jul']
# ['jul', '059']
# ['touchtelindia', '101']
# ['jul', '203']
# ['at', 'jul']
# ['164', '23']
# ['sh', '2005']
# ['82', '16']
# ['connection', '23']
# ['2005', 'jul']
# ['2005', '09']
# ['interxion', '62']
# ['62', '164']
# ['09', '164']
# ['09', '99']
# ['164', '2005']
# ['82', 'inode']
# ['164', '769']
# ['23', '3']
# ['connection', 'interxion']
# ['at', 'sun']
# ['23', '16']
# ['82', 'inode']
# ['sh', '765']
# ['99', 'interxion']
# ['connection', 'jul']
# ['sh', 'sun']
# ['99', '99']
# ['jul', 'at']
# ['23', '16']
# ['sun', '164']
# ['99', '82']
# ['at', '164']
# ['82', '62']
# ['inode', 'from']
# ['164', '23']
# ['from', '164']
# ['23', '99']
# ['at', 'from']
# ['2005', '82']
# ['758', '82']
# ['82', 'interxion']
# ['82', 'sun']
# ['62', '16']
# ['2005', 'sh']
# ['sun', 'from']
# ['82', 'inode']
# ['23', '99']
# ['16', '82']
# ['3', '62']
# ['99', '82']
# ['09', '99']
# ['sh', '16']
# ['at', '82']
# ['82', 'from']
# ['from', '99']
# ['2005', '164']
# ['from', 'inode']
# ['at', 'connection']
# ['756', 'sh']
# ['connection', '23']
# ['3', 'from']
# ['2005', '99']
# ['at', 'inode']
# ['at', '99']
# ['sh', 'connection']
# ['connection', '760']
# ['99', 'from']
# ['interxion', '23']
# ['sun', 'sh']
# ['3', '82']
# ['at', 'connection']
# ['3', 'connection']
# ['82', 'sh']
# ['2005', '164']
# ['sun', 'connection']
# ['62', 'interxion']
# ['99', 'inode']
# ['sh', '771']
# ['62', 'sun']
# ['164', 'connection']
# ['82', '164']
# ['sun', '2005']
# ['16', '09']
# ['164', '62']
# ['776', 'sun']
# ['2005', '09']
# ['82', '99']
# ['interxion', 'connection']
# ['23', '164']
# ['at', '99']
# ['777', 'sun']
# ['from', 'at']
# ['62', '99']
# ['82', '23']
# ['inode', '62']
# ['sh', '3']
# ['connection', 'at']
# ['euid', '0']
# ['2543', 'rhost']
# ['210', 'unix']
# ['authentication', 'failure']
# ['root', 'logname']
# ['mon', 'pacbell']
# ['2005', '4']
# ['at', '2005']
# ['pacbell', '98']
# ['2838', 'mtry01']
# ['jul', 'connection']
# ['net', '197']
# ['net', '12']
# ['pacbell', '44']
# ['2005', 'pacbell']
# ['52', 'net']
# ['jul', '63']
# ['2005', 'at']
# ['2005', '12']
# ['12', 'mtry01']
# ['mtry01', '63']
# ['98', '2005']
# ['106', '197']
# ['2840', 'net']
# ['106', '197']
# ['net', '52']
# ['106', '98']
# ['52', '197']
# ['44', '63']
# ['52', '197']
# ['jul', '98']
# ['2005', '98']
# ['jul', '44']
# ['52', 'mtry01']
# ['44', '63']
# ['mtry01', '63']
# ['63', 'mon']
# ['2829', '12']
# ['106', '106']
# ['106', '106']
# ['pacbell', 'mtry01']
# ['pacbell', 'mtry01']
# ['106', '98']
# ['mtry01', 'dsl']
# ['12', '106']
# ['pacbell', 'mtry01']
# ['197', '44']
# ['connection', '197']
# ['from', 'jul']
# ['63', '12']
# ['197', '4']
# ['2834', '2005']
# ['106', '4']
# ['jul', '98']
# ['from', '197']
# ['106', '4']
# ['12', 'pacbell']
# ['106', '44']
# ['dsl', 'mon']
# ['mon', '44']
# ['63', '63']
# ['98', '44']
# ['at', '63']
# ['12', 'pacbell']
# ['connection', 'mtry01']
# ['52', 'net']
# ['12', '197']
# ['mtry01', '106']
# ['adsl', 'at']
# ['adsl', '98']
# ['44', '12']
# ['jul', '197']
# ['2821', 'jul']
# ['106', 'connection']
# ['106', '197']
# ['106', '106']
# ['197', 'net']
# ['44', '63']
# ['jul', '197']
# ['4', '52']
# ['98', '12']
# ['2005', '63']
# ['net', '197']
# ['63', '63']
# ['63', 'mtry01']
# ['mtry01', 'pacbell']
# ['connection', 'at']
# ['2825', '2005']
# ['197', '2005']
# ['mon', 'dsl']
# ['63', '98']
# ['mon', 'jul']
# ['106', 'mon']
# ['adsl', 'mtry01']
# ['adsl', 'pacbell']
# ['euid', 'failure']
# ['unix', 'rhost']
# ['3384', 'pam']
# ['nodevssh', 'logname']
# ['authentication', 'failure']
# ['nodevssh', '117']
# ['87', 'authentication']
# ['rhost', 'failure']
# ['authentication', '87']
# ['rhost', 'authentication']
# ['3402', 'rhost']
# ['87', '0']
# ['pam', 'tty']
# ['210', '6552']
# ['0', '229']
# ['euid', 'failure']
# ['pass', '6554']
# ['unix', '6554']
# ['unknown', 'check']
# ['euid', 'failure']
# ['logname', '228']
# ['228', 'tty']
# ['210', 'unix']
# ['euid', 'tty']
# ['0', 'nodevssh']
# ['nodevssh', 'pam']
# ['228', 'authentication']
# ['228', 'ruser']
# ['logname', '228']
# ['authentication', 'tty']
# ['106', '211']
# ['connection', '2005']
# ['13', 'at']
# ['tue', 'jul']
# ['5', '52']
# ['2', '6580']
# ['72', '5']
# ['21', 'from']
# ['at', '6580']
# ['106', '13']
# ['at', '6580']
# ['connection', '2005']
# ['21', '2']
# ['at', '106']
# ['72', '2']
# ['2005', '52']
# ['6589', 'at']
# ['2005', '106']
# ['connection', '5']
# ['2005', '2']
# ['5', 'jul']
# ['52', 'from']
# ['52', 'at']
# ['72', '106']
# ['52', 'from']
# ['52', '6586']
# ['13', '5']
# ['52', '21']
# ['connection', '2005']
# ['from', '13']
# ['13', '211']
# ['21', 'connection']
# ['5', 'from']
# ['2', '2005']
# ['2005', '5']
# ['72', '2']
# ['5', '13']
# ['13', 'tue']
# ['2005', 'jul']
# ['2005', '2']
# ['106', '13']
# ['2005', '52']
# ['5', 'connection']
# ['2', '13']
# ['tue', 'jul']
# ['106', '21']
# ['2005', '5']
# ['6588', 'at']
# ['106', '5']
# ['106', '13']
# ['2', '72']
# ['tue', '5']
# ['from', '2']
# ['at', '52']
# ['tue', '6585']
# ['211', 'tue']
# ['2005', '21']
# ['jul', 'at']
# ['at', '13']
# ['at', 'connection']
# ['72', '6584']
# ['tue', 'connection']
# ['from', '2005']
# ['tue', '6593']
# ['tue', '6593']
# ['106', '13']
# ['23', 'connection']
# ['2005', '13']
# ['connection', '13']
# ['jul', 'from']
# ['connection', '13']
# ['at', 'from']
# ['from', 'at']
# ['2005', '52']
# ['tue', '2005']
# ['2005', 'jul']
# ['jul', '23']
# ['106', '5']
# ['jul', '23']
# ['from', '211']
# ['2', '13']
# ['106', 'connection']
# ['jul', '5']
# ['at', '72']
# ['5', 'at']
# ['72', '6597']
# ['at', '211']
# ['2', '13']
# ['from', 'jul']
# ['tue', 'connection']
# ['connection', '23']
# ['tue', 'from']
# ['tue', '72']
# ['from', 'tue']
# ['2005', 'from']
# ['13', '2005']
# ['6599', 'from']
# ['at', '52']
# ['from', '2']
# ['at', '106']
# ['72', 'at']
# ['211', 'from']
# ['jul', '72']
# ['0', 'tty']
# ['7694', 'pam']
# ['0', 'root']
# ['unix', 'root']
# ['rhost', 'euid']
# ['euid', '16']
# ['218', '48']
# ['nodevssh', 'ruser']
# ['48', 'rhost']
# ['0', '122']
# ['ruser', '16']
# ['ruser', 'failure']
# ['122', 'euid']
# ['unix', 'user']
# ['uid', 'opened']
# ['8195', 'unix']
# ['unix', 'session']
# ['8565', 'pam']
# ['unix', 'pam']
# ['162', '2005']
# ['211', 'connection']
# ['6', 'wed']
# ['151', 'connection']
# ['162', 'wed']
# ['18', '211']
# ['9772', '56']
# ['162', '211']
# ['from', '2005']
# ['connection', '56']
# ['9773', '00']
# ['211', '2005']
# ['151', '6']
# ['211', '9773']
# ['2005', '9773']
# ['00', '162']
# ['from', 'jul']
# ['6', '18']
# ['00', '151']
# ['wed', '2005']
# ['211', 'jul']
# ['18', '9777']
# ['18', 'wed']
# ['connection', '6']
# ['connection', '2005']
# ['jul', '2005']
# ['18', 'jul']
# ['72', 'from']
# ['at', 'from']
# ['from', '162']
# ['211', '18']
# ['151', '18']
# ['00', '162']
# ['211', '151']
# ['at', '18']
# ['connection', 'from']
# ['18', '162']
# ['56', '2005']
# ['56', 'at']
# ['wed', '211']
# ['72', '56']
# ['00', '6']
# ['2005', '18']
# ['jul', '00']
# ['jul', 'from']
# ['151', '56']
# ['00', 'wed']
# ['2005', 'wed']
# ['2005', '72']
# ['at', '162']
# ['jul', '56']
# ['56', 'at']
# ['wed', '00']
# ['162', '00']
# ['9771', '18']
# ['6', 'from']
# ['6', '2005']
# ['6', '162']
# ['wed', 'at']
# ['jul', 'wed']
# ['6', 'jul']
# ['9765', 'wed']
# ['wed', '151']
# ['72', '9765']
# ['72', 'wed']
# ['connection', 'at']
# ['72', '211']
# ['6', '162']
# ['72', '9764']
# ['jul', 'from']
# ['72', '56']
# ['jul', '00']
# ['6', '18']
# ['at', '2005']
# ['6', '2005']
# ['151', '211']
# ['56', 'jul']
# ['211', 'from']
# ['00', '18']
# ['connection', '00']
# ['151', 'from']
# ['211', 'connection']
# ['9766', 'connection']
# ['211', '151']
# ['jul', '162']
# ['connection', '00']
# ['connection', '6']
# ['18', 'jul']
# ['162', '6']
# ['00', '151']
# ['at', '56']
# ['2005', '56']
# ['2005', '00']
# ['211', 'at']
# ['jul', '162']
# ['162', '211']
# ['at', '00']
# ['00', '151']
# ['connection', '162']
# ['151', '00']
# ['2005', 'wed']
# ['162', '211']
# ['211', 'connection']
# ['jul', '72']
# ['00', '211']
# ['162', '72']
# ['wed', '56']
# ['151', '162']
# ['18', '9760']
# ['9760', '151']
# ['connection', '211']
# ['from', '162']
# ['00', 'from']
# ['9760', '162']
# ['jul', '00']
# ['18', 'connection']
# ['00', '6']
# ['connection', 'from']
# ['18', '00']
# ['00', '6']
# ['162', 'at']
# ['151', 'at']
# ['162', '2005']
# ['56', '6']
# ['00', '18']
# ['9762', '72']
# ['wed', '211']
# ['72', 'wed']
# ['00', '151']
# ['72', 'wed']
# ['6', 'from']
# ['6', 'jul']
# ['9767', '211']
# ['connection', '2005']
# ['18', '56']
# ['connection', 'from']
# ['151', '211']
# ['18', 'connection']
# ['2005', 'from']
# ['00', '162']
# ['18', '56']
# ['jul', '72']
# ['00', '2005']
# ['151', '162']
# ['from', 'jul']
# ['9768', 'at']
# ['151', 'at']
# ['00', 'from']
# ['9768', 'jul']
# ['6', '2005']
# ['162', '18']
# ['72', '6']
# ['jul', 'connection']
# ['2005', '57']
# ['18', '162']
# ['at', '2005']
# ['at', '00']
# ['jul', '9778']
# ['151', 'jul']
# ['2005', '57']
# ['at', 'from']
# ['connection', 'jul']
# ['10961', 'pam']
# ['for', 'cyrus']
# ['user', '0']
# ['uid', 'unix']
# ['509', 'by']
# ['for', '12519']
# ['opened', 'unix']
# ['509', 'test']
# ['user', 'pam']
# ['mice', 'c']
# ['info', 'c']
# ['info', '1766']
# ['info', 'c']
# ['c', 'info']
# ['2094', 'mice']
# ['2094', 'c']
# ['1766', 'mice']
# ['c', '1766']
# ['2421', 'for']
# ['session', 'unix']
# ['root', 'tty2']
# ['node', '12754']
# ['12754', 'vcsa2']
# ['12754', 'node']
# ['vcsa2', 'udev']
# ['vcs2', 'removing']
# ['vcs2', '12777']
# ['device', '12777']
# ['node', 'vcs2']
# ['node', 'removing']
# ['unknown', 'unix']
# ['33', '13512']
# ['188', '52']
# ['thu', '188']
# ['200', '13512']
# ['from', '200']
# ['13512', '82']
# ['2005', '200']
# ['2005', 'at']
# ['7', '16']
# ['thu', '202']
# ['thu', '52']
# ['jul', 'connection']
# ['jul', '7']
# ['at', '13515']
# ['33', 'from']
# ['at', '33']
# ['2005', '188']
# ['jul', '52']
# ['jul', '52']
# ['33', '82']
# ['connection', '52']
# ['7', 'thu']
# ['16', 'from']
# ['82', '202']
# ['7', 'connection']
# ['connection', '200']
# ['16', '202']
# ['33', '202']
# ['7', '33']
# ['13518', '2005']
# ['82', '2005']
# ['200', 'thu']
# ['2005', '200']
# ['188', 'thu']
# ['connection', '13522']
# ['82', 'jul']
# ['jul', '2005']
# ['2005', 'from']
# ['at', '33']
# ['52', '13517']
# ['33', '7']
# ['16', '13517']
# ['jul', 'at']
# ['at', '7']
# ['16', 'connection']
# ['202', 'thu']
# ['33', '202']
# ['188', '82']
# ['200', 'thu']
# ['connection', '52']
# ['52', '13520']
# ['33', '82']
# ['thu', '202']
# ['thu', '2005']
# ['from', '200']
# ['16', 'thu']
# ['7', '2005']
# ['at', '7']
# ['jul', '13519']
# ['16', '7']
# ['thu', 'at']
# ['16', '2005']
# ['2005', 'jul']
# ['13514', '202']
# ['52', '13514']
# ['connection', 'thu']
# ['2005', '102']
# ['7', 'jul']
# ['45', 'connection']
# ['23', '102']
# ['2005', '09']
# ['from', 'thu']
# ['102', '221']
# ['from', 'jul']
# ['4', '2005']
# ['221', 'connection']
# ['102', 'thu']
# ['102', '23']
# ['connection', 'from']
# ['thu', '4']
# ['jul', 'from']
# ['23', '09']
# ['221', '4']
# ['7', 'at']
# ['from', 'jul']
# ['thu', '2005']
# ['connection', '14108']
# ['14108', '93']
# ['09', 'jul']
# ['102', '2005']
# ['jul', '2005']
# ['14108', '4']
# ['23', '14108']
# ['14108', 'from']
# ['4', '102']
# ['4', '93']
# ['at', '221']
# ['102', '2005']
# ['from', 'thu']
# ['from', 'thu']
# ['14111', 'at']
# ['23', '7']
# ['45', '14111']
# ['45', '2005']
# ['09', '93']
# ['09', '4']
# ['thu', '7']
# ['7', '09']
# ['7', '4']
# ['7', '4']
# ['102', '4']
# ['7', '4']
# ['93', '221']
# ['221', 'from']
# ['45', '102']
# ['from', '09']
# ['thu', '45']
# ['jul', 'from']
# ['2005', 'jul']
# ['jul', 'at']
# ['jul', '93']
# ['2005', '93']
# ['09', '4']
# ['thu', '09']
# ['jul', 'at']
# ['at', '09']
# ['221', '93']
# ['jul', '45']
# ['221', 'from']
# ['thu', 'from']
# ['221', 'from']
# ['thu', 'jul']
# ['2005', '221']
# ['from', 'at']
# ['45', '14117']
# ['221', '4']
# ['93', 'from']
# ['thu', '23']
# ['thu', '14117']
# ['from', '93']
# ['45', 'at']
# ['23', '7']
# ['jul', '93']
# ['2005', '102']
# ['2005', '102']
# ['thu', '47']
# ['23', '14120']
# ['93', '23']
# ['from', '93']
# ['2005', '7']
# ['jul', '7']
# ['47', '93']
# ['102', '50']
# ['from', 'thu']
# ['session', 'pam']
# ['opened', 'pam']
# ['ruser', 'nodevssh']
# ['user', '0']
# ['20', 'failure']
# ['132', '0']
# ['uid', 'unix']
# ['22368', 'by']
# ['user', '0']
# ['news', 'uid']
# ['from', 'sat']
# ['connection', '211']
# ['connection', 'sat']
# ['211', '88']
# ['35', '59']
# ['from', 'sat']
# ['35', 'connection']
# ['211', '57']
# ['sat', '211']
# ['35', 'from']
# ['35', '9']
# ['211', 'connection']
# ['from', '57']
# ['connection', '88']
# ['2005', '59']
# ['23030', '211']
# ['11', 'connection']
# ['57', '35']
# ['11', '57']
# ['88', 'at']
# ['88', 'sat']
# ['sat', '250']
# ['from', '88']
# ['11', '59']
# ['jul', '211']
# ['at', 'from']
# ['2005', '88']
# ['23035', 'sat']
# ['250', '9']
# ['9', '23035']
# ['59', 'from']
# ['connection', 'from']
# ['connection', '35']
# ['211', '250']
# ['from', 'sat']
# ['9', '211']
# ['from', '35']
# ['59', 'at']
# ['57', '59']
# ['9', '23037']
# ['211', '57']
# ['jul', 'at']
# ['250', '2005']
# ['11', '9']
# ['9', 'from']
# ['9', '11']
# ['35', 'from']
# ['9', '35']
# ['88', 'from']
# ['connection', '23029']
# ['57', 'from']
# ['57', 'connection']
# ['88', 'connection']
# ['57', '11']
# ['sat', '57']
# ['35', '88']
# ['2005', 'jul']
# ['57', '211']
# ['59', 'jul']
# ['from', '59']
# ['35', '11']
# ['at', '250']
# ['23048', 'from']
# ['from', 'sat']
# ['from', '23045']
# ['2005', 'connection']
# ['from', '2005']
# ['59', '211']
# ['connection', '23045']
# ['11', 'jul']
# ['at', '250']
# ['59', '88']
# ['connection', '59']
# ['250', 'sat']
# ['connection', '35']
# ['57', '23040']
# ['2005', 'sat']
# ['59', '9']
# ['connection', '11']
# ['9', '35']
# ['jul', '11']
# ['250', '211']
# ['jul', 'at']
# ['11', '59']
# ['2005', '57']
# ['35', '23039']
# ['9', '23039']
# ['sat', '250']
# ['57', 'connection']
# ['250', '57']
# ['35', '59']
# ['sat', '11']
# ['connection', '11']
# ['35', '9']
# ['sat', '57']
# ['sat', '23041']
# ['connection', '59']
# ['88', '57']
# ['at', '88']
# ['at', 'sat']
# ['from', '250']
# ['11', 'jul']
# ['jul', 'connection']
# ['59', '23033']
# ['88', 'connection']
# ['jul', '57']
# ['23033', 'connection']
# ['9', 'sat']
# ['23033', '9']
# ['11', '59']
# ['35', '250']
# ['9', '11']
# ['250', '57']
# ['from', 'sat']
# ['35', 'jul']
# ['9', 'from']
# ['59', 'sat']
# ['11', '35']
# ['jul', 'from']
# ['sat', 'at']
# ['connection', '167']
# ['211', '59']
# ['9', '2005']
# ['59', '23143']
# ['12', 'from']
# ['9', '68']
# ['68', 'sat']
# ['connection', 'at']
# ['sat', '2005']
# ['16', '23142']
# ['49', '211']
# ['from', '23142']
# ['167', '23142']
# ['from', '16']
# ['at', '211']
# ['9', 'sat']
# ['23142', '2005']
# ['connection', '68']
# ['49', '2005']
# ['68', '23141']
# ['2005', 'from']
# ['16', '59']
# ['49', '16']
# ['jul', '16']
# ['12', 'sat']
# ['sat', '68']
# ['jul', '211']
# ['2005', '16']
# ['211', 'connection']
# ['16', 'at']
# ['16', '49']
# ['68', 'at']
# ['167', '12']
# ['211', 'sat']
# ['from', '211']
# ['sat', '49']
# ['at', '23145']
# ['16', 'jul']
# ['68', 'sat']
# ['at', 'sat']
# ['9', 'sat']
# ['9', '2005']
# ['sat', '2005']
# ['9', '2005']
# ['9', 'at']
# ['at', '59']
# ['9', 'jul']
# ['167', '12']
# ['connection', '49']
# ['at', '9']
# ['68', '16']
# ['12', '16']
# ['jul', '49']
# ['2005', 'jul']
# ['9', '49']
# ['49', '167']
# ['59', 'jul']
# ['jul', '49']
# ['9', 'at']
# ['from', '68']
# ['2005', '167']
# ['at', 'from']
# ['9', 'jul']
# ['from', 'connection']
# ['23147', '167']
# ['from', '12']
# ['at', '59']
# ['at', '16']
# ['68', '2005']
# ['jul', 'connection']
# ['211', '2005']
# ['9', '59']
# ['16', '12']
# ['at', '51']
# ['2005', '211']
# ['from', 'sat']
# ['211', '51']
# ['68', '211']
# ['2005', '9']
# ['9', '51']
# ['sat', '9']
# ['16', 'from']
# ['at', 'connection']
# ['12', '51']
# ['59', '68']
# ['23153', 'jul']
# ['167', '51']
# ['sat', '68']
# ['59', '211']
# ['211', '23153']
# ['23153', '68']
# ['sat', '167']
# ['167', '59']
# ['23155', 'connection']
# ['connection', '68']
# ['211', 'jul']
# ['sat', '59']
# ['9', '211']
# ['51', '59']
# ['51', '16']
# ['at', 'sat']
# ['211', '59']
# ['59', 'sat']
# ['23154', '68']
# ['51', 'sat']
# ['jul', 'connection']
# ['9', '59']
# ['jul', 'sat']
# ['59', 'sat']
# ['at', '68']
# ['connection', '59']
# ['2005', 'sat']
# ['connection', '52']
# ['16', 'jul']
# ['jul', '16']
# ['167', '16']
# ['52', 'sat']
# ['220', '59']
# ['at', '220']
# ['9', '226']
# ['171', 'jul']
# ['81', '44']
# ['9', 'sat']
# ['2005', '23204']
# ['jul', 'at']
# ['220', '59']
# ['sat', '9']
# ['220', '44']
# ['220', '44']
# ['jul', 'connection']
# ['220', '44']
# ['220', '12']
# ['jul', '44']
# ['59', 'sat']
# ['sat', 'connection']
# ['connection', 'from']
# ['9', '12']
# ['23217', '44']
# ['12', '226']
# ['226', '9']
# ['23217', '226']
# ['connection', '2005']
# ['59', '23217']
# ['from', 'at']
# ['23206', '9']
# ['sat', 'jul']
# ['at', '220']
# ['59', '9']
# ['226', '81']
# ['12', '23207']
# ['220', 'from']
# ['81', '220']
# ['59', 'from']
# ['171', '9']
# ['226', 'connection']
# ['connection', 'from']
# ['81', '12']
# ['226', 'from']
# ['171', 'connection']
# ['at', 'connection']
# ['81', '23219']
# ['226', '171']
# ['220', '59']
# ['connection', '59']
# ['226', '220']
# ['59', 'connection']
# ['connection', 'jul']
# ['jul', '81']
# ['59', '23210']
# ['44', 'jul']
# ['59', 'sat']
# ['220', 'at']
# ['2005', '171']
# ['at', '23210']
# ['81', '9']
# ['from', '171']
# ['2005', '59']
# ['12', '81']
# ['226', '9']
# ['connection', 'at']
# ['81', '12']
# ['sat', '171']
# ['12', '171']
# ['9', 'connection']
# ['from', '59']
# ['connection', '12']
# ['226', 'connection']
# ['59', '12']
# ['2005', 'at']
# ['171', '81']
# ['226', 'sat']
# ['9', '12']
# ['81', '171']
# ['220', 'at']
# ['81', 'at']
# ['connection', '23212']
# ['jul', '2005']
# ['2005', '9']
# ['2005', '220']
# ['sat', '9']
# ['at', '81']
# ['220', 'from']
# ['sat', '44']
# ['226', '59']
# ['jul', '12']
# ['connection', 'sat']
# ['12', 'from']
# ['220', '59']
# ['12', 'at']
# ['sat', '171']
# ['2005', '81']
# ['171', '44']
# ['9', 'at']
# ['2005', 'sat']
# ['44', '59']
# ['sat', '81']
# ['220', 'from']
# ['2005', '226']
# ['from', 'at']
# ['connection', '2005']
# ['9', 'at']
# ['2005', '226']
# ['44', '226']
# ['9', '2005']
# ['171', 'from']
# ['9', 'from']
# ['sat', 'at']
# ['12', '220']
# ['220', 'jul']
# ['at', '220']
# ['23223', '45']
# ['12', '59']
# ['171', 'connection']
# ['81', '12']
# ['jul', '81']
# ['81', '9']
# ['45', '81']
# ['45', '12']
# ['from', '81']
# ['220', 'sat']
# ['45', 'connection']
# ['171', '81']
# ['12', '171']
# ['at', '45']
# ['226', 'from']
# ['226', '81']
# ['23226', '59']
# ['59', 'sat']
# ['171', '226']
# ['226', '2005']
# ['sat', '81']
# ['connection', 'from']
# ['euid', 'tty']
# ['p15105218', 'root']
# ['uid', 'euid']
# ['23798', 'p15105218']
# ['uid', 'root']
# ['from', '21']
# ['53', '21']
# ['206', 'jul']
# ['206', 'connection']
# ['at', '24085']
# ['19', '24085']
# ['196', 'sat']
# ['com', '9']
# ['24085', 'sat']
# ['22', '196']
# ['21', '206']
# ['206', '24088']
# ['9', 'sat']
# ['53', '129']
# ['53', 'at']
# ['206', '2005']
# ['maximumasp', 'com']
# ['19', 'host129']
# ['21', 'maximumasp']
# ['206', '9']
# ['sat', '24087']
# ['connection', '53']
# ['connection', 'jul']
# ['129', '53']
# ['206', 'at']
# ['196', 'maximumasp']
# ['connection', '129']
# ['24089', '22']
# ['206', 'jul']
# ['com', 'maximumasp']
# ['at', '196']
# ['from', 'maximumasp']
# ['196', 'sat']
# ['206', '9']
# ['maximumasp', '206']
# ['22', 'host129']
# ['19', '196']
# ['19', 'host129']
# ['2005', '206']
# ['22', '206']
# ['com', 'from']
# ['21', 'com']
# ['at', '22']
# ['at', '196']
# ['maximumasp', '196']
# ['206', 'sat']
# ['2005', 'at']
# ['from', 'at']
# ['129', '206']
# ['host129', 'from']
# ['21', 'connection']
# ['206', 'jul']
# ['com', '196']
# ['at', '196']
# ['9', '22']
# ['21', '196']
# ['22', 'jul']
# ['21', '22']
# ['206', 'sat']
# ['21', 'from']
# ['21', '196']
# ['9', '206']
# ['53', '22']
# ['at', '129']
# ['24069', '129']
# ['206', '22']
# ['24069', '129']
# ['connection', 'sat']
# ['21', 'at']
# ['196', '206']
# ['9', '22']
# ['maximumasp', 'com']
# ['24079', 'jul']
# ['206', '24079']
# ['sat', '129']
# ['24079', '196']
# ['jul', '206']
# ['from', 'jul']
# ['22', 'com']
# ['com', '22']
# ['196', '2005']
# ['196', 'maximumasp']
# ['22', 'com']
# ['206', '21']
# ['53', 'from']
# ['host129', '24072']
# ['22', '9']
# ['206', 'host129']
# ['sat', '21']
# ['206', 'jul']
# ['196', '53']
# ['22', '9']
# ['24076', '206']
# ['206', '22']
# ['host129', 'sat']
# ['host129', '196']
# ['22', '2005']
# ['21', '22']
# ['2005', '53']
# ['from', 'jul']
# ['24078', '22']
# ['9', '53']
# ['9', 'sat']
# ['24078', '2005']
# ['at', '21']
# ['53', 'at']
# ['21', '206']
# ['22', '24078']
# ['jul', '22']
# ['53', '22']
# ['21', 'from']
# ['com', 'sat']
# ['53', 'connection']
# ['22', 'maximumasp']
# ['196', '196']
# ['sat', 'connection']
# ['21', '22']
# ['196', 'jul']
# ['connection', '53']
# ['129', '22']
# ['maximumasp', '22']
# ['206', 'from']
# ['jul', 'from']
# ['196', '21']
# ['9', '53']
# ['22', 'maximumasp']
# ['9', 'com']
# ['maximumasp', '21']
# ['2005', 'maximumasp']
# ['at', 'sat']
# ['host129', '2005']
# ['host129', '22']
# ['22', '129']
# ['connection', '22']
# ['21', 'from']
# ['196', '196']
# ['host129', 'maximumasp']
# ['21', '22']
# ['206', 'host129']
# ['from', '2005']
# ['9', '21']
# ['9', 'jul']
# ['24073', 'from']
# ['com', '21']
# ['sat', 'com']
# ['24513', '03']
# ['217', '24513']
# ['55', '83']
# ['at', '83']
# ['187', 'connection']
# ['217', '10']
# ['from', '03']
# ['2005', 'sun']
# ['24513', '55']
# ['83', 'from']
# ['15', '2005']
# ['jul', '24512']
# ['15', '24512']
# ['217', '10']
# ['217', '24512']
# ['139', '217']
# ['from', '10']
# ['83', '10']
# ['187', 'at']
# ['jul', '217']
# ['187', 'at']
# ['03', '55']
# ['jul', '24519']
# ['from', 'at']
# ['connection', '2005']
# ['jul', '187']
# ['15', 'at']
# ['15', '187']
# ['83', 'connection']
# ['83', 'jul']
# ['jul', '03']
# ['03', '15']
# ['at', '83']
# ['connection', '03']
# ['55', '03']
# ['at', '55']
# ['217', 'connection']
# ['187', '24517']
# ['2005', 'connection']
# ['24517', '139']
# ['139', 'connection']
# ['217', 'jul']
# ['10', 'connection']
# ['187', 'connection']
# ['217', '24521']
# ['10', '187']
# ['10', 'connection']
# ['connection', 'at']
# ['03', '10']
# ['83', 'connection']
# ['187', '03']
# ['15', 'sun']
# ['2005', '10']
# ['217', 'connection']
# ['03', '24518']
# ['connection', '187']
# ['10', '24518']
# ['10', 'connection']
# ['15', '03']
# ['24523', '83']
# ['connection', '15']
# ['217', '03']
# ['2005', '217']
# ['at', '55']
# ['03', 'jul']
# ['from', '03']
# ['jul', 'sun']
# ['connection', 'sun']
# ['10', '139']
# ['sun', '2005']
# ['139', 'sun']
# ['15', '55']
# ['187', '83']
# ['187', 'sun']
# ['10', 'sun']
# ['at', '24526']
# ['2005', '24526']
# ['from', '139']
# ['83', '139']
# ['connection', '187']
# ['10', '187']
# ['03', '15']
# ['24527', 'sun']
# ['55', '15']
# ['connection', 'sun']
# ['sun', '15']
# ['24529', 'from']
# ['sun', '139']
# ['187', 'connection']
# ['83', '217']
# ['187', 'connection']
# ['139', '187']
# ['24529', '15']
# ['55', '139']
# ['2005', 'jul']
# ['10', '55']
# ['jul', '83']
# ['139', '2005']
# ['03', '83']
# ['03', '55']
# ['jul', '2005']
# ['2005', 'connection']
# ['sun', '03']
# ['15', 'sun']
# ['connection', '24531']
# ['10', 'sun']
# ['15', '2005']
# ['jul', '10']
# ['139', '83']
# ['217', 'from']
# ['03', '10']
# ['jul', '03']
# ['24532', '55']
# ['10', '2005']
# ['03', '187']
# ['55', 'jul']
# ['217', '15']
# ['from', '55']
# ['55', 'jul']
# ['217', '55']
# ['03', 'connection']
# ['at', '55']
# ['2005', '217']
# ['24533', '2005']
# ['connection', 'from']
# ['jul', '217']
# ['83', '139']
# ['139', '55']
# ['55', 'connection']
# ['connection', 'sun']
# ['closed', '24898']
# ['cyrus', 'closed']
# ['4', '1']
# ['1', '4']
# ['restart', '4']
# ['restart', '1']
# ['4', 'restart']
# ['restart', '1']
# ['1', '4']
# ['restart', '1']
# ['4', '1']
# ['1', 'alert']
# ['with', 'alert']
# ['ip', 'connection']
# ['227', 'net']
# ['083', 'dsl']
# ['07', 'dsl']
# ['083', 'connection']
# ['10', 'arcor']
# ['net', '227']
# ['29723', '67']
# ['227', '07']
# ['24', '24']
# ['07', '083']
# ['07', 'connection']
# ['sun', '083']
# ['arcor', '24']
# ['29720', '24']
# ['67', 'ip']
# ['2005', '082']
# ['29720', '067']
# ['67', '24']
# ['07', '227']
# ['ip', '67']
# ['arcor', 'at']
# ['net', 'arcor']
# ['connection', '10']
# ['net', 'from']
# ['24', 'jul']
# ['07', '67']
# ['arcor', '083']
# ['227', '10']
# ['227', '82']
# ['07', '067']
# ['arcor', '227']
# ['24', 'connection']
# ['07', '24']
# ['83', 'connection']
# ['227', '82']
# ['67', 'arcor']
# ['dsl', 'sun']
# ['connection', '082']
# ['24', '2005']
# ['jul', '2005']
# ['from', '227']
# ['ip', '2005']
# ['24', 'sun']
# ['227', 'from']
# ['2005', '067']
# ['24', '10']
# ['227', 'connection']
# ['dsl', '10']
# ['34', '082']
# ['82', '082']
# ['jul', '067']
# ['from', 'arcor']
# ['07', '2005']
# ['dsl', '227']
# ['arcor', '34']
# ['sun', '29731']
# ['24', '29731']
# ['at', '227']
# ['067', '227']
# ['from', '24']
# ['ip', 'dsl']
# ['connection', '082']
# ['24', '67']
# ['ip', 'net']
# ['82', '082']
# ['10', '2005']
# ['connection', 'at']
# ['067', 'arcor']
# ['34', 'sun']
# ['067', '2005']
# ['82', 'arcor']
# ['arcor', '067']
# ['arcor', '67']
# ['34', 'jul']
# ['ip', '83']
# ['jul', '82']
# ['083', 'from']
# ['227', '34']
# ['67', '24']
# ['067', 'ip']
# ['067', '083']
# ['2005', 'at']
# ['083', '2005']
# ['24', '10']
# ['10', '227']
# ['067', 'net']
# ['sun', '083']
# ['2005', '07']
# ['67', 'net']
# ['067', 'at']
# ['067', '82']
# ['83', 'at']
# ['dsl', '29737']
# ['jul', '082']
# ['arcor', 'sun']
# ['83', 'arcor']
# ['from', 'net']
# ['2005', 'ip']
# ['067', '082']
# ['067', '2005']
# ['82', 'dsl']
# ['83', '083']
# ['24', '29735']
# ['connection', 'ip']
# ['29736', 'arcor']
# ['ip', 'at']
# ['at', '17']
# ['connection', '10']
# ['sun', 'connection']
# ['from', '22']
# ['17', '22']
# ['connection', '13']
# ['at', '30276']
# ['94', '205']
# ['94', '45']
# ['30276', '94']
# ['10', '13']
# ['13', '10']
# ['220', 'sun']
# ['45', '10']
# ['at', 'from']
# ['jul', '10']
# ['from', '17']
# ['17', '30292']
# ['94', '30292']
# ['94', 'at']
# ['220', 'at']
# ['220', '10']
# ['94', '10']
# ['13', 'connection']
# ['13', 'jul']
# ...
# ['188', '42']
# ['206', 'at']
# ['188', '206']
# ['211', '24']
# ['09', '24']
# ['at', '09']
# ['fri', '2005']
# ['2005', '188']
# ['jul', 'from']
# ['at', '27']
# ['22', '2005']
# ['211', 'from']
# ['at', '09']
# ['jul', 'connection']
# ['connection', '09']
# ['from', '09']
# ['42', '24']
# ['27', 'connection']
# ['connection', '27']
# ['2005', 'at']
# ['22', '24']
# ['2005', '188']
# ['27', '2005']
# ['at', '188']
# ['from', 'connection']
# ['connection', '22']
# ['fri', '2005']
# ['jul', '22']
# ['24', '09']
# ['27', '22']
# ['24', '2005']
# ['at', '188']
# ['2005', '22']
# ['27', 'at']
# ['24', '211']
# ['24', '09']
# ['22', 'jul']
# ['09', '27']
# ['jul', 'at']
# ['jul', '22']
# ['jul', '49']
# ['95', '29']
# ['fri', '49']
# ['172', '22']
# ['fri', '22']
# ['2005', '22']
# ['13152', '95']
# ['09', '49']
# ['67', '29']
# ['67', '22']
# ['jul', '09']
# ['13150', 'jul']
# ['from', '19']
# ['from', 'fri']
# ['2005', '13147']
# ['at', '13147']
# ['at', 'jul']
# ['49', '22']
# ['connection', '2005']
# ['19', '2005']
# ['22', 'fri']
# ['172', '13149']
# ['2005', '29']
# ['connection', '09']
# ['19', '22']
# ['fri', '13149']
# ['jul', '29']
# ['67', 'fri']
# ['172', '09']
# ['09', 'connection']
# ['19', '13148']
# ['connection', '29']
# ['95', '172']
# ['09', 'fri']
# ['67', '13148']
# ['19', 'connection']
# ['jul', 'at']
# ['2005', '67']
# ['from', '19']
# ['29', '13141']
# ['fri', 'from']
# ['at', '49']
# ['connection', '09']
# ['jul', '49']
# ['67', '09']
# ['49', 'jul']
# ['67', 'from']
# ['jul', '19']
# ['67', '09']
# ['67', '22']
# ['95', '13140']
# ['at', '95']
# ['09', '19']
# ['95', '29']
# ['jul', '95']
# ['19', '22']
# ['fri', 'from']
# ['from', '95']
# ['29', 'fri']
# ['22', '95']
# ['2005', 'from']
# ['at', '29']
# ['at', '67']
# ['49', '2005']
# ['22', 'at']
# ['22', 'at']
# ['13143', 'connection']
# ['09', 'jul']
# ['67', '29']
# ['172', '67']
# ['13143', '172']
# ['19', '09']
# ['at', '19']
# ['95', '13143']
# ['49', '67']
# ['19', '2005']
# ['connection', 'jul']
# ['95', '2005']
# ['jul', '95']
# ['2005', 'jul']
# ['13144', 'at']
# ['fri', '13144']
# ['19', '29']
# ['09', '95']
# ['22', 'fri']
# ['172', '19']
# ['67', 'at']
# ['connection', '19']
# ['67', '22']
# ['at', 'from']
# ['95', '09']
# ['fri', '13155']
# ['fri', 'at']
# ['95', '29']
# ['13156', '49']
# ['172', 'connection']
# ['13156', 'from']
# ['2005', 'fri']
# ['172', '67']
# ['49', '13156']
# ['from', '49']
# ['67', '09']
# ['jul', 'from']
# ['09', 'jul']
# ['connection', '2005']
# ['from', 'fri']
# ['13159', 'connection']
# ['49', '13159']
# ['09', '19']
# ['29', '19']
# ['2005', 'at']
# ['at', 'fri']
# ['connection', '22']
# ['172', '22']
# ['13160', 'connection']
# ['2005', '67']
# ['49', '09']
# ['172', '49']
# ['connection', '49']
# ['09', 'at']
# ['67', '22']
# ['49', 'fri']
# ['19', 'connection']
# ['67', '13161']
# ['jul', '09']
# ['jul', '172']
# ['49', '09']
# ['2005', '22']
# ['67', '22']
# ['29', 'from']
# ['95', '29']
# ['49', 'at']
# ['22', '95']
# ['49', '13162']
# ['95', '22']
# ['29', 'from']
# ['19', 'jul']
# ['from', '22']
# ['2005', '10']
# ['euid', 'tty']
# ['failure', 'logname']
# ['logname', 'nodevssh']
# ['uid', 'nodevssh']
# ['uid', 'rhost']
# ['9', '16154']
# ['authentication', 'root']
# ['16153', '0']
# ['0', 'ruser']
# ['authentication', 'tty']
# ['38', '84']
# ['at', '24']
# ['84', '102']
# ['84', '16773']
# ['38', '16773']
# ['38', 'sun']
# ['connection', '20']
# ['84', '38']
# ['2005', '102']
# ['20', '84']
# ['22', 'sun']
# ['24', '2']
# ['16789', 'sun']
# ['sun', '20']
# ['at', '22']
# ['2', '2005']
# ['16789', '2005']
# ['16789', '24']
# ['102', '16783']
# ['2005', 'connection']
# ['38', '2']
# ['jul', '24']
# ['2005', '2']
# ['at', '20']
# ['from', 'jul']
# ['102', '20']
# ['24', 'at']
# ['20', 'sun']
# ['connection', '02']
# ['from', '2']
# ['20', '2005']
# ['sun', '38']
# ['22', 'from']
# ['102', '38']
# ['at', 'jul']
# ['22', 'jul']
# ['jul', '102']
# ['20', 'connection']
# ['at', 'from']
# ['102', '38']
# ['20', '102']
# ['2005', 'at']
# ['at', '2005']
# ['22', 'at']
# ['24', 'jul']
# ['2005', 'from']
# ['20', '102']
# ['jul', '102']
# ['at', 'sun']
# ['84', '16790']
# ['20', '102']
# ['16790', 'from']
# ['sun', '102']
# ['22', '16790']
# ['02', '24']
# ['2', 'at']
# ['from', 'sun']
# ['at', '84']
# ['16780', 'sun']
# ['jul', '22']
# ['38', 'jul']
# ['38', '22']
# ['38', 'from']
# ['sun', '102']
# ['at', '20']
# ['22', '24']
# ['sun', '2']
# ['20', '02']
# ['20', 'jul']
# ['02', '24']
# ['84', 'connection']
# ['at', 'jul']
# ['jul', '20']
# ['sun', '22']
# ['20', '38']
# ['2', '20']
# ['24', '2005']
# ['2', '20']
# ['22', 'connection']
# ['38', 'sun']
# ['24', 'connection']
# ['02', '24']
# ['38', '22']
# ['16787', '24']
# ['2005', '38']
# ['02', '20']
# ['22', 'connection']
# ['84', 'at']
# ['sun', '16787']
# ['2005', 'at']
# ['22', '24']
# ['02', 'from']
# ['16774', 'connection']
# ['38', 'connection']
# ['sun', 'connection']
# ['jul', '02']
# ['jul', '84']
# ['38', 'at']
# ['2', 'connection']
# ['38', '84']
# ['22', '102']
# ['22', '16772']
# ['38', '16772']
# ['2005', 'connection']
# ['2', '22']
# ['24', 'from']
# ['2', 'from']
# ['22', '38']
# ['jul', '2']
# ['102', '22']
# ['at', '102']
# ['102', '38']
# ['24', '2005']
# ['at', 'jul']
# ['2005', '102']
# ['20', 'jul']
# ['from', '2005']
# ['sun', 'connection']
# ['from', 'connection']
# ['2', '24']
# ['jul', '2']
# ['102', 'sun']
# ['02', 'jul']
# ['jul', 'from']
# ['02', 'jul']
# ['16793', '24']
# ['84', 'at']
# ['84', '22']
# ['84', 'jul']
# ['20', 'from']
# ['2', '2005']
# ['sun', 'jul']
# ['sun', '84']
# ['2', 'from']
# ['22', 'sun']
# ['at', '20']
# ['38', '2005']
# ['at', '24']
# ['2', '20']
# ['connection', '22']
# ['from', '20']
# ['from', '84']
# ['20', '84']
# ['anonymous', 'ftp']
# ['102', '84']
# ['16782', '84']
# ['ftp', '16782']
# ['anonymous', '102']
# ['16782', 'anonymous']
# ['anonymous', 'anonymous']
# ['4', 'restart']
# ['1', '1']
# ['1', 'restart']
# ['1', '1']
# ['1', '1']
# ['1', 'restart']
# ['restart', '1']
# ['1', '1']
# ['1', 'restart']
# ['for', 'by']
# ['ruser', 'unix']
# ['ruser', '0']
# ['root', 'logname']
# ['225', 'authentication']
# ['pam', '251']
# ['203', 'pam']
# ['euid', '203']
# ['logname', 'nodevssh']
# ['225', 'rhost']
# ['root', 'pam']
# ['211', '1']
# ['connection', '46']
# ['jul', '107']
# ['sun', '107']
# ['from', '1']
# ['1', '211']
# ['jul', '107']
# ['sun', 'jul']
# ['22658', '1']
# ['2005', 'from']
# ['232', '2005']
# ['from', '211']
# ['32', 'sun']
# ['at', 'connection']
# ['13', 'from']
# ['211', '13']
# ['24', 'from']
# ['2005', '32']
# ['46', '32']
# ['22653', 'jul']
# ['sun', '32']
# ['211', '46']
# ['22653', '24']
# ['46', 'connection']
# ['24', '46']
# ['2005', '107']
# ['32', '2005']
# ['jul', '1']
# ['24', 'from']
# ['22657', 'at']
# ['22657', 'sun']
# ['22657', 'at']
# ['sun', '24']
# ['211', 'at']
# ['jul', 'from']
# ['22656', '32']
# ['32', '232']
# ['1', 'at']
# ['32', '2005']
# ['1', '24']
# ['from', '1']
# ['22656', '24']
# ['107', '32']
# ['24', '232']
# ['1', '211']
# ['211', 'sun']
# ['32', 'connection']
# ['2005', 'sun']
# ['connection', '1']
# ['connection', '211']
# ['22651', '211']
# ['22651', '32']
# ['13', '211']
# ['1', '22654']
# ['22654', 'from']
# ['1', 'at']
# ['2005', '32']
# ['connection', '107']
# ['13', '46']
# ['jul', 'at']
# ['24', '107']
# ['232', '46']
# ['connection', '34']
# ['connection', '24']
# ['24', '211']
# ['from', 'at']
# ['jul', '34']
# ['1', '232']
# ['24', 'jul']
# ['46', 'connection']
# ['211', 'connection']
# ['1', '13']
# ['connection', '1']
# ['13', 'from']
# ['jul', '13']
# ['211', '34']
# ['13', 'connection']
# ['connection', 'at']
# ['46', '232']
# ['107', '211']
# ['2005', '211']
# ['at', 'from']
# ['107', '24']
# ['at', '107']
# ['at', '211']
# ['1', 'connection']
# ['34', 'from']
# ['at', 'jul']
# ['at', '46']
# ['13', '107']
# ['211', '22667']
# ['sun', '13']
# ['34', '2005']
# ['jul', '46']
# ['1', 'at']
# ['jul', '22667']
# ['22667', '46']
# ['jul', '1']
# ['22664', '211']
# ['sun', '1']
# ['232', '22664']
# ['232', '211']
# ['sun', '24']
# ['22664', '24']
# ['46', '22664']
# ['sun', 'at']
# ['107', 'connection']
# ['46', '2005']
# ['211', '107']
# ['connection', 'jul']
# ['211', '1']
# ['22669', '35']
# ['2005', '1']
# ['from', '1']
# ['1', '2005']
# ['connection', 'sun']
# ['1', 'alert']
# ['with', 'alert']
# ['connection', 'at']
# ['2005', 'from']
# ['209', '10']
# ['39', 'from']
# ['at', '206']
# ['47', '10']
# ['39', 'from']
# ['10', 'jul']
# ['10', '206']
# ['jul', 'at']
# ['47', '209']
# ['47', '10']
# ['206', '39']
# ['24972', '06']
# ['from', '2005']
# ['10', '2005']
# ['47', 'from']
# ['jul', '2005']
# ['39', '10']
# ['209', '2005']
# ['06', '18']
# ['at', 'jul']
# ['10', '2005']
# ['mon', '47']
# ['06', '209']
# ['24976', '47']
# ['mon', '06']
# ['2005', 'connection']
# ['209', 'at']
# ['209', 'at']
# ['18', '06']
# ['206', '39']
# ['06', '25']
# ['209', 'connection']
# ['10', 'at']
# ['connection', '10']
# ['206', '47']
# ['10', '18']
# ['24974', 'connection']
# ['from', 'connection']
# ['18', '39']
# ['connection', '206']
# ['06', '47']
# ['18', '206']
# ['jul', '06']
# ['jul', '10']
# ['2005', '25']
# ['24973', '25']
# ['connection', '39']
# ['39', '47']
# ['connection', 'from']
# ['206', '209']
# ['from', 'at']
# ['connection', '209']
# ['from', '18']
# ['2005', '10']
# ['25', '24962']
# ['mon', '209']
# ['209', '24962']
# ['at', 'jul']
# ['209', '206']
# ['206', 'jul']
# ['06', 'jul']
# ['at', '2005']
# ['18', 'connection']
# ['18', '206']
# ['06', '24966']
# ['from', '209']
# ['206', 'from']
# ['at', '209']
# ['at', '25']
# ['06', '10']
# ['18', '06']
# ['47', '206']
# ['10', 'from']
# ['jul', '47']
# ['206', '39']
# ['39', '10']
# ['from', '39']
# ['2005', 'mon']
# ['jul', '47']
# ['2005', '10']
# ['06', 'jul']
# ['connection', '25']
# ['2005', '24965']
# ['mon', '06']
# ['jul', '39']
# ['10', '18']
# ['jul', '18']
# ['mon', '18']
# ['2005', 'from']
# ['10', '06']
# ['from', 'jul']
# ['at', '206']
# ['47', '06']
# ['47', '2005']
# ['from', '39']
# ['jul', '206']
# ['25', '206']
# ['209', 'connection']
# ['10', '2005']
# ['connection', 'jul']
# ['18', '10']
# ['206', '209']
# ['24956', '18']
# ['18', 'at']
# ['206', '06']
# ['206', 'from']
# ['connection', '2005']
# ['jul', '24956']
# ['mon', '47']
# ['24957', 'mon']
# ['at', '18']
# ['from', '10']
# ['206', '18']
# ['2005', '209']
# ['at', 'jul']
# ['10', '206']
# ['47', 'connection']
# ['18', 'connection']
# ['from', 'connection']
# ['18', '47']
# ['18', '47']
# ['10', '47']
# ['10', '39']
# ['at', 'connection']
# ['mon', '10']
# ['18', '06']
# ['2005', 'at']
# ['39', '47']
# ['06', '18']
# ['10', 'from']
# ['2005', 'at']
# ['18', 'connection']
# ['47', '206']
# ['206', '18']
# ['206', '18']
# ['24963', 'mon']
# ['10', '2005']
# ['connection', '24963']
# ['18', 'at']
# ['39', 'jul']
# ['2005', '47']
# ['2005', '47']
# ['25', '24961']
# ['25', 'mon']
# ['25', '24961']
# ['206', 'mon']
# ['25', 'connection']
# ['from', '39']
# ['06', 'mon']
# ['06', '18']
# ['at', '18']
# ['section', 'no']
# ['question', 'section']
# ['notify', '2306']
# ['section', 'no']
# ['section', 'no']
# ['reset', 't']
# ['by', 'client']
# ['is', '26484']
# ['getpeername', 'transport']
# ['24', 'from']
# ['24', '25']
# ['at', '09']
# ['2005', '26479']
# ['at', '26479']
# ['25', '26479']
# ['jul', '217']
# ['24', 'from']
# ['jul', '09']
# ['24', '25']
# ['mon', '23']
# ['at', '2005']
# ['connection', '09']
# ['2005', '187']
# ['connection', 'from']
# ['09', '187']
# ['2005', '25']
# ['26477', '2005']
# ['mon', '83']
# ['187', '83']
# ['2005', '24']
# ['26477', '09']
# ['mon', 'at']
# ['26476', 'at']
# ['24', '23']
# ['187', '25']
# ['mon', '50']
# ['24', '23']
# ['jul', '2005']
# ['connection', '24']
# ['jul', 'at']
# ['24', '09']
# ['09', '25']
# ['217', '83']
# ['50', '187']
# ['83', 'mon']
# ['mon', '217']
# ['50', '83']
# ['09', '217']
# ['mon', '83']
# ['jul', '187']
# ['from', '23']
# ['50', 'from']
# ['50', '26474']
# ['jul', '09']
# ['50', 'connection']
# ['50', '217']
# ['217', '83']
# ['jul', 'at']
# ['26473', '50']
# ['23', 'jul']
# ['2005', '23']
# ['83', '187']
# ['23', '24']
# ['09', '187']
# ['2005', '24']
# ['24', 'from']
# ['from', 'connection']
# ['83', '187']
# ['mon', '83']
# ['09', '83']
# ['from', '2005']
# ['jul', '23']
# ['83', '187']
# ['jul', '09']
# ['24', '25']
# ['24', 'connection']
# ['83', '26472']
# ['24', 'from']
# ['connection', '25']
# ['from', '50']
# ['2005', 'jul']
# ['50', '24']
# ['217', '187']
# ['at', '23']
# ['2005', '23']
# ['from', 'mon']
# ['from', 'at']
# ['25', '217']
# ['mon', '26469']
# ['217', '09']
# ['mon', 'connection']
# ['83', '25']
# ['26464', '83']
# ['connection', 'at']
# ['connection', 'at']
# ['from', '23']
# ['jul', '50']
# ['83', 'at']
# ['jul', 'connection']
# ['25', '217']
# ['23', '26481']
# ['24', 'connection']
# ['217', 'mon']
# ['83', '26481']
# ['at', '25']
# ['26481', '25']
# ['09', 'connection']
# ['25', '2005']
# ['50', '24']
# ['23', 'mon']
# ['mon', '217']
# ['2005', '83']
# ['23', 'at']
# ['connection', '83']
# ['187', 'at']
# ['connection', '50']
# ['25', '217']
# ['mon', '217']
# ['09', 'at']
# ['jul', '187']
# ['83', 'jul']
# ['25', '23']
# ['50', '23']
# ['26485', '83']
# ['24', '25']
# ['at', '23']
# ['session', '27285']
# ['user', 'for']
# ['news', 'session']
# ['from', '26']
# ['208', 'connection']
# ['jul', '172']
# ['tue', '26']
# ['connection', '181']
# ['181', '208']
# ['at', '05']
# ['jul', '2005']
# ['connection', '26']
# ['42', '47']
# ['47', '42']
# ['05', 'tue']
# ['208', 'tue']
# ['26', '28703']
# ['47', 'at']
# ['connection', 'at']
# ['from', '26']
# ['26', 'connection']
# ['from', '208']
# ['172', '181']
# ['28700', '172']
# ['156', '208']
# ['47', 'at']
# ['156', 'connection']
# ['from', 'tue']
# ['181', '42']
# ['172', '208']
# ['42', '26']
# ['connection', 'tue']
# ['47', 'connection']
# ['from', 'tue']
# ['47', 'jul']
# ['tue', '42']
# ['from', '26']
# ['at', 'connection']
# ['208', '47']
# ['47', '156']
# ['208', 'connection']
# ['26', '181']
# ['47', 'at']
# ['from', 'connection']
# ['at', 'from']
# ['172', '181']
# ['at', 'tue']
# ['47', '42']
# ['connection', '181']
# ['47', 'at']
# ['tue', 'at']
# ['2005', 'jul']
# ['42', '26']
# ['2005', 'at']
# ['47', '156']
# ['connection', '156']
# ['connection', '181']
# ['connection', '47']
# ['jul', '156']
# ['28693', 'connection']
# ['42', '05']
# ['172', '05']
# ['28689', '208']
# ['tue', '42']
# ['172', '05']
# ['05', '172']
# ['2005', '156']
# ['connection', '47']
# ['jul', 'at']
# ['tue', '156']
# ['connection', '42']
# ['208', '26']
# ['2005', 'at']
# ['26', '42']
# ['jul', '47']
# ['from', '156']
# ['42', '172']
# ['05', '26']
# ['26', '208']
# ['26', 'tue']
# ['28686', '2005']
# ['42', 'jul']
# ['208', 'tue']
# ['26', '42']
# ['2005', '172']
# ['tue', 'from']
# ['28687', '2005']
# ['from', 'jul']
# ['28688', 'from']
# ['from', '26']
# ['05', '156']
# ['28688', '172']
# ['156', '28688']
# ['47', '28688']
# ['181', '42']
# ['42', '2005']
# ['2005', '208']
# ['connection', '47']
# ['at', '26']
# ['156', 'from']
# ['jul', 'at']
# ['tue', '181']
# ['156', '47']
# ['from', '181']
# ['172', '26']
# ['connection', '156']
# ['05', '156']
# ['jul', '05']
# ['2005', '51']
# ['05', '156']
# ['at', '05']
# ['47', '28706']
# ['at', '51']
# ['28706', 'connection']
# ['26', 'from']
# ['47', '156']
# ['2005', 'at']
# ['156', '2005']
# ['05', 'jul']
# ['28707', '172']
# ['2005', '51']
# ['51', '28707']
# ['from', 'jul']
# ['47', '156']
# ['at', 'from']
# ['207', 'user']
# ['114', 'root']
# ['authentication', 'tty']
# ['nodevssh', 'euid']
# ['ruser', 'nodevssh']
# ['28852', '114']
# ['pam', 'failure']
# ['nodevssh', '167']
# ['243', 'rhost']
# ['207', '0']
# ['0', '207']
# ['rhost', 'ruser']
# ['unix', '243']
# ['nodevssh', 'tty']
# ['nodevssh', '0']
# ['unix', 'euid']
# ['243', 'unix']
# ['pam', 'authentication']
# ['167', 'unix']
# ['167', 'tty']
# ['nodevssh', '243']
# ['uid', 'pam']
# ['nodevssh', 'root']
# ['user', '28870']
# ['0', 'ruser']
# ['logname', 'ruser']
# ['167', 'uid']
# ['nodevssh', 'euid']
# ['167', 'failure']
# ['rhost', 'authentication']
# ['ruser', '114']
# ['167', '207']
# ['28876', '207']
# ['unix', 'pam']
# ['nodevssh', 'failure']
# ['ruser', '0']
# ['pam', '114']
# ['167', '114']
# ['failure', 'pam']
# ['euid', '114']
# ['tty', 'uid']
# ['114', '0']
# ['euid', '114']
# ['pam', '0']
# ['failure', 'uid']
# ['closed', 'unix']
# ['53', 'at']
# ['59', 'at']
# ['10', '38']
# ['59', '10']
# ['218', '10']
# ['wed', 'jul']
# ['4', '1']
# ['1', '1']
# ['1', '4']
# ['1', 'restart']
# ['restart', '1']
# ['1', '4']
# ['1', 'restart']
# ['restart', '1']
# ['4', '1']
# ['sat', '1']
# ['8', 'version']
# ['3', 'may']
# ['8', 'version']
# ['com', 'sat']
# ['0000000007eae000', 'e820']
# ['0', '32430']
# ['32430', 'totalpages']
# ['node', '32430']
# ['32430', 'on']
# ['totalpages', '32430']
# ['0', 'on']
# ['on', 'node']
# ['batch', 'zone']
# ['1', 'pages']
# ['highmem', 'zone']
# ['2', '3']
# ['3', 'present']
# ['3', '2']
# ['dmi', 'present']
# ['built', '1']
# ['1', 'zonelists']
# ['built', '1']
# ['built', 'zonelists']
# ['cpu', '0']
# ['cpu', '0']
# ['cpu', 'initializing']
# ['02345000', 'cpu']
# ['soft', 'irqstacks']
# ['entries', '4096']
# ['4096', 'pid']
# ['table', '512']
# ['table', 'entries']
# ['731', 'processor']
# ['detected', '731']
# ['processor', 'mhz']
# ['version', '6']
# ['statd', '0']
# ['version', 'starting']
# ['security', '0']
# ['initialized', 'scaffold']
# ['i', 'd']
# ['cache', 'cpu']
# ['cpu', 'stepping']
# ['registered', 'protocol']
# ['last', 'entry']
# ['pci', 'using']
# ['v2', '0']
# ['0', 'v2']
# ['20020519', '0']
# ['mtrr', '20020519']
# ['mtrr', '20020519']
# ['20020519', 'v2']
# ['mtrr', 'v2']
# ['revision', 'subsystem']
# ['1e', '00']
# ['transparent', '0000']
# ['1e', 'transparent']
# ['ver', '1690']
# ['4', '1690']
# ['4', 'ver']
# ['started', 'hci']
# ['initialized', 'audit']
# ['pci', 'core']
# ['c', 'interface']
# ['100', 'c']
# ['interface', 'linux']
